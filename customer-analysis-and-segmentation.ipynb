# %% [markdown]
# # Customer Personality Analysis & Segmentation

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering
from yellowbrick.cluster import KElbowVisualizer

import warnings
warnings.filterwarnings('ignore')


from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>

# %% [markdown]
# **About Dataset**

# %% [markdown]
# * **ID:** Customer's unique identifier
# * **Year_Birth:** Customer's birth year
# * **Education:** Customer's education level
# * **Marital_Status:** Customer's marital status
# * **Income:** Customer's yearly household income
# * **Kidhome:** Number of children in customer's household
# * **Teenhome:** Number of teenagers in customer's household
# * **Dt_Customer:** Date of customer's enrollment with the company
# * **Recency:** Number of days since customer's last purchase
# * **Complain:** 1 if the customer complained in the last 2 years, 0 otherwise
# * **MntWines:** Amount spent on wine in last 2 years
# * **MntFruits:** Amount spent on fruits in last 2 years
# * **MntMeatProducts:** Amount spent on meat in last 2 years
# * **MntFishProducts:** Amount spent on fish in last 2 years
# * **MntSweetProducts:** Amount spent on sweets in last 2 years
# * **MntGoldProds:** Amount spent on gold in last 2 years
# * **NumDealsPurchases:** Number of purchases made with a discount
# * **AcceptedCmp1:** 1 if customer accepted the offer in the 1st campaign, 0 otherwise
# * **AcceptedCmp2:** 1 if customer accepted the offer in the 2nd campaign, 0 otherwise
# * **AcceptedCmp3:** 1 if customer accepted the offer in the 3rd campaign, 0 otherwise
# * **AcceptedCmp4:** 1 if customer accepted the offer in the 4th campaign, 0 otherwise
# * **AcceptedCmp5:** 1 if customer accepted the offer in the 5th campaign, 0 otherwise
# * **Response:** 1 if customer accepted the offer in the last campaign, 0 otherwise
# * **NumWebPurchases:** Number of purchases made through the company’s website
# * **NumCatalogPurchases:** Number of purchases made using a catalogue
# * **NumStorePurchases:** Number of purchases made directly in stores
# * **NumWebVisitsMonth:** Number of visits to company’s website in the last month

# %%
data = pd.read_csv("~/Downloads/marketing_campaign.csv.xls", sep="\t")

# %% [markdown]
# **Basic Exploration**
#
#
# Let's have a glimpse of the dataset.

# %%
print(f"Shape Of The Dataset : {data.shape}")
print(f"\nGlimpse Of The Dataset :")
data.head().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Shape Of The Dataset : (2240, 29)
#
# Glimpse Of The Dataset :
# <style type="text/css">
# #T_a0b71_row0_col0, #T_a0b71_row0_col1, #T_a0b71_row0_col2, #T_a0b71_row0_col3, #T_a0b71_row0_col4, #T_a0b71_row0_col5, #T_a0b71_row0_col6, #T_a0b71_row0_col7, #T_a0b71_row0_col8, #T_a0b71_row0_col9, #T_a0b71_row0_col10, #T_a0b71_row0_col11, #T_a0b71_row0_col12, #T_a0b71_row0_col13, #T_a0b71_row0_col14, #T_a0b71_row0_col15, #T_a0b71_row0_col16, #T_a0b71_row0_col17, #T_a0b71_row0_col18, #T_a0b71_row0_col19, #T_a0b71_row0_col20, #T_a0b71_row0_col21, #T_a0b71_row0_col22, #T_a0b71_row0_col23, #T_a0b71_row0_col24, #T_a0b71_row0_col25, #T_a0b71_row0_col26, #T_a0b71_row0_col27, #T_a0b71_row0_col28, #T_a0b71_row1_col0, #T_a0b71_row1_col1, #T_a0b71_row1_col2, #T_a0b71_row1_col3, #T_a0b71_row1_col4, #T_a0b71_row1_col5, #T_a0b71_row1_col6, #T_a0b71_row1_col7, #T_a0b71_row1_col8, #T_a0b71_row1_col9, #T_a0b71_row1_col10, #T_a0b71_row1_col11, #T_a0b71_row1_col12, #T_a0b71_row1_col13, #T_a0b71_row1_col14, #T_a0b71_row1_col15, #T_a0b71_row1_col16, #T_a0b71_row1_col17, #T_a0b71_row1_col18, #T_a0b71_row1_col19, #T_a0b71_row1_col20, #T_a0b71_row1_col21, #T_a0b71_row1_col22, #T_a0b71_row1_col23, #T_a0b71_row1_col24, #T_a0b71_row1_col25, #T_a0b71_row1_col26, #T_a0b71_row1_col27, #T_a0b71_row1_col28, #T_a0b71_row2_col0, #T_a0b71_row2_col1, #T_a0b71_row2_col2, #T_a0b71_row2_col3, #T_a0b71_row2_col4, #T_a0b71_row2_col5, #T_a0b71_row2_col6, #T_a0b71_row2_col7, #T_a0b71_row2_col8, #T_a0b71_row2_col9, #T_a0b71_row2_col10, #T_a0b71_row2_col11, #T_a0b71_row2_col12, #T_a0b71_row2_col13, #T_a0b71_row2_col14, #T_a0b71_row2_col15, #T_a0b71_row2_col16, #T_a0b71_row2_col17, #T_a0b71_row2_col18, #T_a0b71_row2_col19, #T_a0b71_row2_col20, #T_a0b71_row2_col21, #T_a0b71_row2_col22, #T_a0b71_row2_col23, #T_a0b71_row2_col24, #T_a0b71_row2_col25, #T_a0b71_row2_col26, #T_a0b71_row2_col27, #T_a0b71_row2_col28, #T_a0b71_row3_col0, #T_a0b71_row3_col1, #T_a0b71_row3_col2, #T_a0b71_row3_col3, #T_a0b71_row3_col4, #T_a0b71_row3_col5, #T_a0b71_row3_col6, #T_a0b71_row3_col7, #T_a0b71_row3_col8, #T_a0b71_row3_col9, #T_a0b71_row3_col10, #T_a0b71_row3_col11, #T_a0b71_row3_col12, #T_a0b71_row3_col13, #T_a0b71_row3_col14, #T_a0b71_row3_col15, #T_a0b71_row3_col16, #T_a0b71_row3_col17, #T_a0b71_row3_col18, #T_a0b71_row3_col19, #T_a0b71_row3_col20, #T_a0b71_row3_col21, #T_a0b71_row3_col22, #T_a0b71_row3_col23, #T_a0b71_row3_col24, #T_a0b71_row3_col25, #T_a0b71_row3_col26, #T_a0b71_row3_col27, #T_a0b71_row3_col28, #T_a0b71_row4_col0, #T_a0b71_row4_col1, #T_a0b71_row4_col2, #T_a0b71_row4_col3, #T_a0b71_row4_col4, #T_a0b71_row4_col5, #T_a0b71_row4_col6, #T_a0b71_row4_col7, #T_a0b71_row4_col8, #T_a0b71_row4_col9, #T_a0b71_row4_col10, #T_a0b71_row4_col11, #T_a0b71_row4_col12, #T_a0b71_row4_col13, #T_a0b71_row4_col14, #T_a0b71_row4_col15, #T_a0b71_row4_col16, #T_a0b71_row4_col17, #T_a0b71_row4_col18, #T_a0b71_row4_col19, #T_a0b71_row4_col20, #T_a0b71_row4_col21, #T_a0b71_row4_col22, #T_a0b71_row4_col23, #T_a0b71_row4_col24, #T_a0b71_row4_col25, #T_a0b71_row4_col26, #T_a0b71_row4_col27, #T_a0b71_row4_col28 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_a0b71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0b71_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_a0b71_level0_col1" class="col_heading level0 col1" >Year_Birth</th>
#       <th id="T_a0b71_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_a0b71_level0_col3" class="col_heading level0 col3" >Marital_Status</th>
#       <th id="T_a0b71_level0_col4" class="col_heading level0 col4" >Income</th>
#       <th id="T_a0b71_level0_col5" class="col_heading level0 col5" >Kidhome</th>
#       <th id="T_a0b71_level0_col6" class="col_heading level0 col6" >Teenhome</th>
#       <th id="T_a0b71_level0_col7" class="col_heading level0 col7" >Dt_Customer</th>
#       <th id="T_a0b71_level0_col8" class="col_heading level0 col8" >Recency</th>
#       <th id="T_a0b71_level0_col9" class="col_heading level0 col9" >MntWines</th>
#       <th id="T_a0b71_level0_col10" class="col_heading level0 col10" >MntFruits</th>
#       <th id="T_a0b71_level0_col11" class="col_heading level0 col11" >MntMeatProducts</th>
#       <th id="T_a0b71_level0_col12" class="col_heading level0 col12" >MntFishProducts</th>
#       <th id="T_a0b71_level0_col13" class="col_heading level0 col13" >MntSweetProducts</th>
#       <th id="T_a0b71_level0_col14" class="col_heading level0 col14" >MntGoldProds</th>
#       <th id="T_a0b71_level0_col15" class="col_heading level0 col15" >NumDealsPurchases</th>
#       <th id="T_a0b71_level0_col16" class="col_heading level0 col16" >NumWebPurchases</th>
#       <th id="T_a0b71_level0_col17" class="col_heading level0 col17" >NumCatalogPurchases</th>
#       <th id="T_a0b71_level0_col18" class="col_heading level0 col18" >NumStorePurchases</th>
#       <th id="T_a0b71_level0_col19" class="col_heading level0 col19" >NumWebVisitsMonth</th>
#       <th id="T_a0b71_level0_col20" class="col_heading level0 col20" >AcceptedCmp3</th>
#       <th id="T_a0b71_level0_col21" class="col_heading level0 col21" >AcceptedCmp4</th>
#       <th id="T_a0b71_level0_col22" class="col_heading level0 col22" >AcceptedCmp5</th>
#       <th id="T_a0b71_level0_col23" class="col_heading level0 col23" >AcceptedCmp1</th>
#       <th id="T_a0b71_level0_col24" class="col_heading level0 col24" >AcceptedCmp2</th>
#       <th id="T_a0b71_level0_col25" class="col_heading level0 col25" >Complain</th>
#       <th id="T_a0b71_level0_col26" class="col_heading level0 col26" >Z_CostContact</th>
#       <th id="T_a0b71_level0_col27" class="col_heading level0 col27" >Z_Revenue</th>
#       <th id="T_a0b71_level0_col28" class="col_heading level0 col28" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0b71_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0b71_row0_col0" class="data row0 col0" >5524</td>
#       <td id="T_a0b71_row0_col1" class="data row0 col1" >1957</td>
#       <td id="T_a0b71_row0_col2" class="data row0 col2" >Graduation</td>
#       <td id="T_a0b71_row0_col3" class="data row0 col3" >Single</td>
#       <td id="T_a0b71_row0_col4" class="data row0 col4" >58138.000000</td>
#       <td id="T_a0b71_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_a0b71_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_a0b71_row0_col7" class="data row0 col7" >04-09-2012</td>
#       <td id="T_a0b71_row0_col8" class="data row0 col8" >58</td>
#       <td id="T_a0b71_row0_col9" class="data row0 col9" >635</td>
#       <td id="T_a0b71_row0_col10" class="data row0 col10" >88</td>
#       <td id="T_a0b71_row0_col11" class="data row0 col11" >546</td>
#       <td id="T_a0b71_row0_col12" class="data row0 col12" >172</td>
#       <td id="T_a0b71_row0_col13" class="data row0 col13" >88</td>
#       <td id="T_a0b71_row0_col14" class="data row0 col14" >88</td>
#       <td id="T_a0b71_row0_col15" class="data row0 col15" >3</td>
#       <td id="T_a0b71_row0_col16" class="data row0 col16" >8</td>
#       <td id="T_a0b71_row0_col17" class="data row0 col17" >10</td>
#       <td id="T_a0b71_row0_col18" class="data row0 col18" >4</td>
#       <td id="T_a0b71_row0_col19" class="data row0 col19" >7</td>
#       <td id="T_a0b71_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_a0b71_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_a0b71_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_a0b71_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_a0b71_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_a0b71_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_a0b71_row0_col26" class="data row0 col26" >3</td>
#       <td id="T_a0b71_row0_col27" class="data row0 col27" >11</td>
#       <td id="T_a0b71_row0_col28" class="data row0 col28" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a0b71_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0b71_row1_col0" class="data row1 col0" >2174</td>
#       <td id="T_a0b71_row1_col1" class="data row1 col1" >1954</td>

# %%
print(f"Informations Of The Dataset :\n")
print(data.info())
# Out:
# Informations Of The Dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
#  16  NumWebPurchases      2240 non-null   int64
#  17  NumCatalogPurchases  2240 non-null   int64
#  18  NumStorePurchases    2240 non-null   int64
#  19  NumWebVisitsMonth    2240 non-null   int64
#  20  AcceptedCmp3         2240 non-null   int64
#  21  AcceptedCmp4         2240 non-null   int64
#  22  AcceptedCmp5         2240 non-null   int64
#  23  AcceptedCmp1         2240 non-null   int64
#  24  AcceptedCmp2         2240 non-null   int64
#  25  Complain             2240 non-null   int64
#  26  Z_CostContact        2240 non-null   int64
#  27  Z_Revenue            2240 non-null   int64
#  28  Response             2240 non-null   int64
# dtypes: float64(1), int64(25), object(3)
# memory usage: 507.6+ KB
# None

# %% [markdown]
# **Dataset Summary**

# %%
print(f"Summary Of The Dataset :")
data.describe().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Summary Of The Dataset :
# <style type="text/css">
# #T_813cc_row0_col0, #T_813cc_row0_col1, #T_813cc_row0_col2, #T_813cc_row0_col3, #T_813cc_row0_col4, #T_813cc_row0_col5, #T_813cc_row0_col6, #T_813cc_row0_col7, #T_813cc_row0_col8, #T_813cc_row0_col9, #T_813cc_row0_col10, #T_813cc_row0_col11, #T_813cc_row0_col12, #T_813cc_row0_col13, #T_813cc_row0_col14, #T_813cc_row0_col15, #T_813cc_row0_col16, #T_813cc_row0_col17, #T_813cc_row0_col18, #T_813cc_row0_col19, #T_813cc_row0_col20, #T_813cc_row0_col21, #T_813cc_row0_col22, #T_813cc_row0_col23, #T_813cc_row0_col24, #T_813cc_row0_col25, #T_813cc_row1_col0, #T_813cc_row1_col1, #T_813cc_row1_col2, #T_813cc_row1_col3, #T_813cc_row1_col4, #T_813cc_row1_col5, #T_813cc_row1_col6, #T_813cc_row1_col7, #T_813cc_row1_col8, #T_813cc_row1_col9, #T_813cc_row1_col10, #T_813cc_row1_col11, #T_813cc_row1_col12, #T_813cc_row1_col13, #T_813cc_row1_col14, #T_813cc_row1_col15, #T_813cc_row1_col16, #T_813cc_row1_col17, #T_813cc_row1_col18, #T_813cc_row1_col19, #T_813cc_row1_col20, #T_813cc_row1_col21, #T_813cc_row1_col22, #T_813cc_row1_col23, #T_813cc_row1_col24, #T_813cc_row1_col25, #T_813cc_row2_col0, #T_813cc_row2_col1, #T_813cc_row2_col2, #T_813cc_row2_col3, #T_813cc_row2_col4, #T_813cc_row2_col5, #T_813cc_row2_col6, #T_813cc_row2_col7, #T_813cc_row2_col8, #T_813cc_row2_col9, #T_813cc_row2_col10, #T_813cc_row2_col11, #T_813cc_row2_col12, #T_813cc_row2_col13, #T_813cc_row2_col14, #T_813cc_row2_col15, #T_813cc_row2_col16, #T_813cc_row2_col17, #T_813cc_row2_col18, #T_813cc_row2_col19, #T_813cc_row2_col20, #T_813cc_row2_col21, #T_813cc_row2_col22, #T_813cc_row2_col23, #T_813cc_row2_col24, #T_813cc_row2_col25, #T_813cc_row3_col0, #T_813cc_row3_col1, #T_813cc_row3_col2, #T_813cc_row3_col3, #T_813cc_row3_col4, #T_813cc_row3_col5, #T_813cc_row3_col6, #T_813cc_row3_col7, #T_813cc_row3_col8, #T_813cc_row3_col9, #T_813cc_row3_col10, #T_813cc_row3_col11, #T_813cc_row3_col12, #T_813cc_row3_col13, #T_813cc_row3_col14, #T_813cc_row3_col15, #T_813cc_row3_col16, #T_813cc_row3_col17, #T_813cc_row3_col18, #T_813cc_row3_col19, #T_813cc_row3_col20, #T_813cc_row3_col21, #T_813cc_row3_col22, #T_813cc_row3_col23, #T_813cc_row3_col24, #T_813cc_row3_col25, #T_813cc_row4_col0, #T_813cc_row4_col1, #T_813cc_row4_col2, #T_813cc_row4_col3, #T_813cc_row4_col4, #T_813cc_row4_col5, #T_813cc_row4_col6, #T_813cc_row4_col7, #T_813cc_row4_col8, #T_813cc_row4_col9, #T_813cc_row4_col10, #T_813cc_row4_col11, #T_813cc_row4_col12, #T_813cc_row4_col13, #T_813cc_row4_col14, #T_813cc_row4_col15, #T_813cc_row4_col16, #T_813cc_row4_col17, #T_813cc_row4_col18, #T_813cc_row4_col19, #T_813cc_row4_col20, #T_813cc_row4_col21, #T_813cc_row4_col22, #T_813cc_row4_col23, #T_813cc_row4_col24, #T_813cc_row4_col25, #T_813cc_row5_col0, #T_813cc_row5_col1, #T_813cc_row5_col2, #T_813cc_row5_col3, #T_813cc_row5_col4, #T_813cc_row5_col5, #T_813cc_row5_col6, #T_813cc_row5_col7, #T_813cc_row5_col8, #T_813cc_row5_col9, #T_813cc_row5_col10, #T_813cc_row5_col11, #T_813cc_row5_col12, #T_813cc_row5_col13, #T_813cc_row5_col14, #T_813cc_row5_col15, #T_813cc_row5_col16, #T_813cc_row5_col17, #T_813cc_row5_col18, #T_813cc_row5_col19, #T_813cc_row5_col20, #T_813cc_row5_col21, #T_813cc_row5_col22, #T_813cc_row5_col23, #T_813cc_row5_col24, #T_813cc_row5_col25, #T_813cc_row6_col0, #T_813cc_row6_col1, #T_813cc_row6_col2, #T_813cc_row6_col3, #T_813cc_row6_col4, #T_813cc_row6_col5, #T_813cc_row6_col6, #T_813cc_row6_col7, #T_813cc_row6_col8, #T_813cc_row6_col9, #T_813cc_row6_col10, #T_813cc_row6_col11, #T_813cc_row6_col12, #T_813cc_row6_col13, #T_813cc_row6_col14, #T_813cc_row6_col15, #T_813cc_row6_col16, #T_813cc_row6_col17, #T_813cc_row6_col18, #T_813cc_row6_col19, #T_813cc_row6_col20, #T_813cc_row6_col21, #T_813cc_row6_col22, #T_813cc_row6_col23, #T_813cc_row6_col24, #T_813cc_row6_col25, #T_813cc_row7_col0, #T_813cc_row7_col1, #T_813cc_row7_col2, #T_813cc_row7_col3, #T_813cc_row7_col4, #T_813cc_row7_col5, #T_813cc_row7_col6, #T_813cc_row7_col7, #T_813cc_row7_col8, #T_813cc_row7_col9, #T_813cc_row7_col10, #T_813cc_row7_col11, #T_813 ...
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_813cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_813cc_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_813cc_level0_col1" class="col_heading level0 col1" >Year_Birth</th>
#       <th id="T_813cc_level0_col2" class="col_heading level0 col2" >Income</th>
#       <th id="T_813cc_level0_col3" class="col_heading level0 col3" >Kidhome</th>
#       <th id="T_813cc_level0_col4" class="col_heading level0 col4" >Teenhome</th>
#       <th id="T_813cc_level0_col5" class="col_heading level0 col5" >Recency</th>
#       <th id="T_813cc_level0_col6" class="col_heading level0 col6" >MntWines</th>
#       <th id="T_813cc_level0_col7" class="col_heading level0 col7" >MntFruits</th>
#       <th id="T_813cc_level0_col8" class="col_heading level0 col8" >MntMeatProducts</th>
#       <th id="T_813cc_level0_col9" class="col_heading level0 col9" >MntFishProducts</th>
#       <th id="T_813cc_level0_col10" class="col_heading level0 col10" >MntSweetProducts</th>
#       <th id="T_813cc_level0_col11" class="col_heading level0 col11" >MntGoldProds</th>
#       <th id="T_813cc_level0_col12" class="col_heading level0 col12" >NumDealsPurchases</th>
#       <th id="T_813cc_level0_col13" class="col_heading level0 col13" >NumWebPurchases</th>
#       <th id="T_813cc_level0_col14" class="col_heading level0 col14" >NumCatalogPurchases</th>
#       <th id="T_813cc_level0_col15" class="col_heading level0 col15" >NumStorePurchases</th>
#       <th id="T_813cc_level0_col16" class="col_heading level0 col16" >NumWebVisitsMonth</th>
#       <th id="T_813cc_level0_col17" class="col_heading level0 col17" >AcceptedCmp3</th>
#       <th id="T_813cc_level0_col18" class="col_heading level0 col18" >AcceptedCmp4</th>
#       <th id="T_813cc_level0_col19" class="col_heading level0 col19" >AcceptedCmp5</th>
#       <th id="T_813cc_level0_col20" class="col_heading level0 col20" >AcceptedCmp1</th>
#       <th id="T_813cc_level0_col21" class="col_heading level0 col21" >AcceptedCmp2</th>
#       <th id="T_813cc_level0_col22" class="col_heading level0 col22" >Complain</th>
#       <th id="T_813cc_level0_col23" class="col_heading level0 col23" >Z_CostContact</th>
#       <th id="T_813cc_level0_col24" class="col_heading level0 col24" >Z_Revenue</th>
#       <th id="T_813cc_level0_col25" class="col_heading level0 col25" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_813cc_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_813cc_row0_col0" class="data row0 col0" >2240.000000</td>
#       <td id="T_813cc_row0_col1" class="data row0 col1" >2240.000000</td>
#       <td id="T_813cc_row0_col2" class="data row0 col2" >2216.000000</td>
#       <td id="T_813cc_row0_col3" class="data row0 col3" >2240.000000</td>
#       <td id="T_813cc_row0_col4" class="data row0 col4" >2240.000000</td>
#       <td id="T_813cc_row0_col5" class="data row0 col5" >2240.000000</td>
#       <td id="T_813cc_row0_col6" class="data row0 col6" >2240.000000</td>
#       <td id="T_813cc_row0_col7" class="data row0 col7" >2240.000000</td>
#       <td id="T_813cc_row0_col8" class="data row0 col8" >2240.000000</td>
#       <td id="T_813cc_row0_col9" class="data row0 col9" >2240.000000</td>
#       <td id="T_813cc_row0_col10" class="data row0 col10" >2240.000000</td>
#       <td id="T_813cc_row0_col11" class="data row0 col11" >2240.000000</td>
#       <td id="T_813cc_row0_col12" class="data row0 col12" >2240.000000</td>
#       <td id="T_813cc_row0_col13" class="data row0 col13" >2240.000000</td>
#       <td id="T_813cc_row0_col14" class="data row0 col14" >2240.000000</td>
#       <td id="T_813cc_r

# %%
data.describe(include=object).T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_f9c56_row0_col0, #T_f9c56_row0_col1, #T_f9c56_row0_col2, #T_f9c56_row0_col3, #T_f9c56_row1_col0, #T_f9c56_row1_col1, #T_f9c56_row1_col2, #T_f9c56_row1_col3, #T_f9c56_row2_col0, #T_f9c56_row2_col1, #T_f9c56_row2_col2, #T_f9c56_row2_col3 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_f9c56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9c56_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_f9c56_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_f9c56_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_f9c56_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9c56_level0_row0" class="row_heading level0 row0" >Education</th>
#       <td id="T_f9c56_row0_col0" class="data row0 col0" >2240</td>
#       <td id="T_f9c56_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_f9c56_row0_col2" class="data row0 col2" >Graduation</td>
#       <td id="T_f9c56_row0_col3" class="data row0 col3" >1127</td>
#     </tr>
#     <tr>
#       <th id="T_f9c56_level0_row1" class="row_heading level0 row1" >Marital_Status</th>
#       <td id="T_f9c56_row1_col0" class="data row1 col0" >2240</td>
#       <td id="T_f9c56_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_f9c56_row1_col2" class="data row1 col2" >Married</td>
#       <td id="T_f9c56_row1_col3" class="data row1 col3" >864</td>
#     </tr>
#     <tr>
#       <th id="T_f9c56_level0_row2" class="row_heading level0 row2" >Dt_Customer</th>
#       <td id="T_f9c56_row2_col0" class="data row2 col0" >2240</td>
#       <td id="T_f9c56_row2_col1" class="data row2 col1" >663</td>
#       <td id="T_f9c56_row2_col2" class="data row2 col2" >31-08-2012</td>
#       <td id="T_f9c56_row2_col3" class="data row2 col3" >12</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(f"Null values of the Dataset :")
data.isna().sum().to_frame().T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Null values of the Dataset :
# <style type="text/css">
# #T_1ebd5_row0_col0, #T_1ebd5_row0_col1, #T_1ebd5_row0_col2, #T_1ebd5_row0_col3, #T_1ebd5_row0_col4, #T_1ebd5_row0_col5, #T_1ebd5_row0_col6, #T_1ebd5_row0_col7, #T_1ebd5_row0_col8, #T_1ebd5_row0_col9, #T_1ebd5_row0_col10, #T_1ebd5_row0_col11, #T_1ebd5_row0_col12, #T_1ebd5_row0_col13, #T_1ebd5_row0_col14, #T_1ebd5_row0_col15, #T_1ebd5_row0_col16, #T_1ebd5_row0_col17, #T_1ebd5_row0_col18, #T_1ebd5_row0_col19, #T_1ebd5_row0_col20, #T_1ebd5_row0_col21, #T_1ebd5_row0_col22, #T_1ebd5_row0_col23, #T_1ebd5_row0_col24, #T_1ebd5_row0_col25, #T_1ebd5_row0_col26, #T_1ebd5_row0_col27, #T_1ebd5_row0_col28 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_1ebd5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ebd5_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_1ebd5_level0_col1" class="col_heading level0 col1" >Year_Birth</th>
#       <th id="T_1ebd5_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_1ebd5_level0_col3" class="col_heading level0 col3" >Marital_Status</th>
#       <th id="T_1ebd5_level0_col4" class="col_heading level0 col4" >Income</th>
#       <th id="T_1ebd5_level0_col5" class="col_heading level0 col5" >Kidhome</th>
#       <th id="T_1ebd5_level0_col6" class="col_heading level0 col6" >Teenhome</th>
#       <th id="T_1ebd5_level0_col7" class="col_heading level0 col7" >Dt_Customer</th>
#       <th id="T_1ebd5_level0_col8" class="col_heading level0 col8" >Recency</th>
#       <th id="T_1ebd5_level0_col9" class="col_heading level0 col9" >MntWines</th>
#       <th id="T_1ebd5_level0_col10" class="col_heading level0 col10" >MntFruits</th>
#       <th id="T_1ebd5_level0_col11" class="col_heading level0 col11" >MntMeatProducts</th>
#       <th id="T_1ebd5_level0_col12" class="col_heading level0 col12" >MntFishProducts</th>
#       <th id="T_1ebd5_level0_col13" class="col_heading level0 col13" >MntSweetProducts</th>
#       <th id="T_1ebd5_level0_col14" class="col_heading level0 col14" >MntGoldProds</th>
#       <th id="T_1ebd5_level0_col15" class="col_heading level0 col15" >NumDealsPurchases</th>
#       <th id="T_1ebd5_level0_col16" class="col_heading level0 col16" >NumWebPurchases</th>
#       <th id="T_1ebd5_level0_col17" class="col_heading level0 col17" >NumCatalogPurchases</th>
#       <th id="T_1ebd5_level0_col18" class="col_heading level0 col18" >NumStorePurchases</th>
#       <th id="T_1ebd5_level0_col19" class="col_heading level0 col19" >NumWebVisitsMonth</th>
#       <th id="T_1ebd5_level0_col20" class="col_heading level0 col20" >AcceptedCmp3</th>
#       <th id="T_1ebd5_level0_col21" class="col_heading level0 col21" >AcceptedCmp4</th>
#       <th id="T_1ebd5_level0_col22" class="col_heading level0 col22" >AcceptedCmp5</th>
#       <th id="T_1ebd5_level0_col23" class="col_heading level0 col23" >AcceptedCmp1</th>
#       <th id="T_1ebd5_level0_col24" class="col_heading level0 col24" >AcceptedCmp2</th>
#       <th id="T_1ebd5_level0_col25" class="col_heading level0 col25" >Complain</th>
#       <th id="T_1ebd5_level0_col26" class="col_heading level0 col26" >Z_CostContact</th>
#       <th id="T_1ebd5_level0_col27" class="col_heading level0 col27" >Z_Revenue</th>
#       <th id="T_1ebd5_level0_col28" class="col_heading level0 col28" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ebd5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ebd5_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_1ebd5_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_1ebd5_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_1ebd5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1ebd5_row0_col4" class="data row0 col4" >24</td>
#       <td id="T_1ebd5_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_1ebd5_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_1ebd5_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_1ebd5_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_1ebd5_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_1ebd5_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_1ebd5_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_1ebd5_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_1ebd5_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_1ebd5_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_1ebd5_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_1ebd5_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_1ebd5_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_1ebd5_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_1ebd5_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_1ebd5_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_1ebd5_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_1ebd5_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_1ebd5_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_1ebd5_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_1ebd5_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_1ebd5_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_1ebd5_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_1ebd5_row0_col28" class="data row0 col28" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Insights:**
#
# * There are missing values in **Income**. We will drop the rows that have missing income values.
# * **Dt_Customer** that indicates the date a customer joined in this dataset is not parsed as DateTime.
# * We will encode the categorical features into numerical form later.

# %% [markdown]
# # Data Preprocessing

# %%
data.dropna(axis = 0, inplace = True)
print(f"After dropping null values, the shape of the Dataset is {data.shape}")
print(f"After dropping null values, null values of the Dataset :")
data.isna().sum().to_frame().T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After dropping null values, the shape of the Dataset is (2216, 29)
# After dropping null values, null values of the Dataset :
# <style type="text/css">
# #T_f7079_row0_col0, #T_f7079_row0_col1, #T_f7079_row0_col2, #T_f7079_row0_col3, #T_f7079_row0_col4, #T_f7079_row0_col5, #T_f7079_row0_col6, #T_f7079_row0_col7, #T_f7079_row0_col8, #T_f7079_row0_col9, #T_f7079_row0_col10, #T_f7079_row0_col11, #T_f7079_row0_col12, #T_f7079_row0_col13, #T_f7079_row0_col14, #T_f7079_row0_col15, #T_f7079_row0_col16, #T_f7079_row0_col17, #T_f7079_row0_col18, #T_f7079_row0_col19, #T_f7079_row0_col20, #T_f7079_row0_col21, #T_f7079_row0_col22, #T_f7079_row0_col23, #T_f7079_row0_col24, #T_f7079_row0_col25, #T_f7079_row0_col26, #T_f7079_row0_col27, #T_f7079_row0_col28 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_f7079">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7079_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_f7079_level0_col1" class="col_heading level0 col1" >Year_Birth</th>
#       <th id="T_f7079_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_f7079_level0_col3" class="col_heading level0 col3" >Marital_Status</th>
#       <th id="T_f7079_level0_col4" class="col_heading level0 col4" >Income</th>
#       <th id="T_f7079_level0_col5" class="col_heading level0 col5" >Kidhome</th>
#       <th id="T_f7079_level0_col6" class="col_heading level0 col6" >Teenhome</th>
#       <th id="T_f7079_level0_col7" class="col_heading level0 col7" >Dt_Customer</th>
#       <th id="T_f7079_level0_col8" class="col_heading level0 col8" >Recency</th>
#       <th id="T_f7079_level0_col9" class="col_heading level0 col9" >MntWines</th>
#       <th id="T_f7079_level0_col10" class="col_heading level0 col10" >MntFruits</th>
#       <th id="T_f7079_level0_col11" class="col_heading level0 col11" >MntMeatProducts</th>
#       <th id="T_f7079_level0_col12" class="col_heading level0 col12" >MntFishProducts</th>
#       <th id="T_f7079_level0_col13" class="col_heading level0 col13" >MntSweetProducts</th>
#       <th id="T_f7079_level0_col14" class="col_heading level0 col14" >MntGoldProds</th>
#       <th id="T_f7079_level0_col15" class="col_heading level0 col15" >NumDealsPurchases</th>
#       <th id="T_f7079_level0_col16" class="col_heading level0 col16" >NumWebPurchases</th>
#       <th id="T_f7079_level0_col17" class="col_heading level0 col17" >NumCatalogPurchases</th>
#       <th id="T_f7079_level0_col18" class="col_heading level0 col18" >NumStorePurchases</th>
#       <th id="T_f7079_level0_col19" class="col_heading level0 col19" >NumWebVisitsMonth</th>
#       <th id="T_f7079_level0_col20" class="col_heading level0 col20" >AcceptedCmp3</th>
#       <th id="T_f7079_level0_col21" class="col_heading level0 col21" >AcceptedCmp4</th>
#       <th id="T_f7079_level0_col22" class="col_heading level0 col22" >AcceptedCmp5</th>
#       <th id="T_f7079_level0_col23" class="col_heading level0 col23" >AcceptedCmp1</th>
#       <th id="T_f7079_level0_col24" class="col_heading level0 col24" >AcceptedCmp2</th>
#       <th id="T_f7079_level0_col25" class="col_heading level0 col25" >Complain</th>
#       <th id="T_f7079_level0_col26" class="col_heading level0 col26" >Z_CostContact</th>
#       <th id="T_f7079_level0_col27" class="col_heading level0 col27" >Z_Revenue</th>
#       <th id="T_f7079_level0_col28" class="col_heading level0 col28" >Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7079_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7079_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_f7079_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_f7079_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_f7079_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f7079_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f7079_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_f7079_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_f7079_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_f7079_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_f7079_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_f7079_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_f7079_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_f7079_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_f7079_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_f7079_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_f7079_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_f7079_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_f7079_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_f7079_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_f7079_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_f7079_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_f7079_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_f7079_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_f7079_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_f7079_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_f7079_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_f7079_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_f7079_row0_col27" class="data row0 col27" >0</td>
#       <td id="T_f7079_row0_col28" class="data row0 col28" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
data["Dt_Customer"] = pd.to_datetime(data["Dt_Customer"], format="%d-%m-%Y")

dates = []
for i in data["Dt_Customer"]:
    dates.append(i.date())

print(f"Newest customer's enrolment date is {max(dates)}")
print(f"Oldest customer's enrolment date is {min(dates)}")
# Out:
# Newest customer's enrolment date is 2014-06-29
# Oldest customer's enrolment date is 2012-07-30

# %%
days = []
newest = max(dates) 
for i in dates:
    duration = newest - i
    days.append(duration)
data["Customer Loyalty"] = days
data["Customer Loyalty"] = data["Customer Loyalty"].dt.days
data["Age"] = 2015 - data["Year_Birth"]
data["Spent"] = data["MntWines"] + data["MntFruits"] + data["MntMeatProducts"] + data["MntFishProducts"] + data["MntSweetProducts"] + data["MntGoldProds"]
data["Children"] = data["Kidhome"] + data["Teenhome"]
data["Parental Status"] = np.where(data["Children"] > 0, 1, 0)
data["Marital_Status"].replace({"Married":"Couple", "Together":"Couple", "Absurd":"Alone", "Widow":"Alone", "YOLO":"Alone", "Divorced":"Alone", "Single":"Alone"}, inplace = True)
data["Education"].replace({"Basic":"Undergraduate","2n Cycle":"Undergraduate", "Graduation":"Graduate", "Master":"Postgraduate", "PhD":"Postgraduate"}, inplace = True)
data["Total Promo"] =  data["AcceptedCmp1"]+ data["AcceptedCmp2"]+ data["AcceptedCmp3"]+ data["AcceptedCmp4"]+ data["AcceptedCmp5"]
data.rename(columns={"Marital_Status": "Marital Status","MntWines": "Wines","MntFruits":"Fruits","MntMeatProducts":"Meat","MntFishProducts":"Fish","MntSweetProducts":"Sweets","MntGoldProds":"Gold","NumWebPurchases": "Web","NumCatalogPurchases":"Catalog","NumStorePurchases":"Store","NumDealsPurchases":"Discount Purchases"}, inplace = True)
data = data[["ID","Age","Education","Marital Status","Parental Status","Children","Kidhome","Teenhome","Income","Spent","Customer Loyalty","Recency","Wines","Fruits","Meat","Fish","Sweets","Gold","Web","Catalog","Store","Discount Purchases","Total Promo","NumWebVisitsMonth"]]

data = data[data["Age"] < 90]
data = data[data["Income"] < 600000]

# %%
print("After preprocessing, let's have a glimpse of the final dataset :")
data.head().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After preprocessing, let's have a glimpse of the final dataset :
# <style type="text/css">
# #T_e03b5_row0_col0, #T_e03b5_row0_col1, #T_e03b5_row0_col2, #T_e03b5_row0_col3, #T_e03b5_row0_col4, #T_e03b5_row0_col5, #T_e03b5_row0_col6, #T_e03b5_row0_col7, #T_e03b5_row0_col8, #T_e03b5_row0_col9, #T_e03b5_row0_col10, #T_e03b5_row0_col11, #T_e03b5_row0_col12, #T_e03b5_row0_col13, #T_e03b5_row0_col14, #T_e03b5_row0_col15, #T_e03b5_row0_col16, #T_e03b5_row0_col17, #T_e03b5_row0_col18, #T_e03b5_row0_col19, #T_e03b5_row0_col20, #T_e03b5_row0_col21, #T_e03b5_row0_col22, #T_e03b5_row0_col23, #T_e03b5_row1_col0, #T_e03b5_row1_col1, #T_e03b5_row1_col2, #T_e03b5_row1_col3, #T_e03b5_row1_col4, #T_e03b5_row1_col5, #T_e03b5_row1_col6, #T_e03b5_row1_col7, #T_e03b5_row1_col8, #T_e03b5_row1_col9, #T_e03b5_row1_col10, #T_e03b5_row1_col11, #T_e03b5_row1_col12, #T_e03b5_row1_col13, #T_e03b5_row1_col14, #T_e03b5_row1_col15, #T_e03b5_row1_col16, #T_e03b5_row1_col17, #T_e03b5_row1_col18, #T_e03b5_row1_col19, #T_e03b5_row1_col20, #T_e03b5_row1_col21, #T_e03b5_row1_col22, #T_e03b5_row1_col23, #T_e03b5_row2_col0, #T_e03b5_row2_col1, #T_e03b5_row2_col2, #T_e03b5_row2_col3, #T_e03b5_row2_col4, #T_e03b5_row2_col5, #T_e03b5_row2_col6, #T_e03b5_row2_col7, #T_e03b5_row2_col8, #T_e03b5_row2_col9, #T_e03b5_row2_col10, #T_e03b5_row2_col11, #T_e03b5_row2_col12, #T_e03b5_row2_col13, #T_e03b5_row2_col14, #T_e03b5_row2_col15, #T_e03b5_row2_col16, #T_e03b5_row2_col17, #T_e03b5_row2_col18, #T_e03b5_row2_col19, #T_e03b5_row2_col20, #T_e03b5_row2_col21, #T_e03b5_row2_col22, #T_e03b5_row2_col23, #T_e03b5_row3_col0, #T_e03b5_row3_col1, #T_e03b5_row3_col2, #T_e03b5_row3_col3, #T_e03b5_row3_col4, #T_e03b5_row3_col5, #T_e03b5_row3_col6, #T_e03b5_row3_col7, #T_e03b5_row3_col8, #T_e03b5_row3_col9, #T_e03b5_row3_col10, #T_e03b5_row3_col11, #T_e03b5_row3_col12, #T_e03b5_row3_col13, #T_e03b5_row3_col14, #T_e03b5_row3_col15, #T_e03b5_row3_col16, #T_e03b5_row3_col17, #T_e03b5_row3_col18, #T_e03b5_row3_col19, #T_e03b5_row3_col20, #T_e03b5_row3_col21, #T_e03b5_row3_col22, #T_e03b5_row3_col23, #T_e03b5_row4_col0, #T_e03b5_row4_col1, #T_e03b5_row4_col2, #T_e03b5_row4_col3, #T_e03b5_row4_col4, #T_e03b5_row4_col5, #T_e03b5_row4_col6, #T_e03b5_row4_col7, #T_e03b5_row4_col8, #T_e03b5_row4_col9, #T_e03b5_row4_col10, #T_e03b5_row4_col11, #T_e03b5_row4_col12, #T_e03b5_row4_col13, #T_e03b5_row4_col14, #T_e03b5_row4_col15, #T_e03b5_row4_col16, #T_e03b5_row4_col17, #T_e03b5_row4_col18, #T_e03b5_row4_col19, #T_e03b5_row4_col20, #T_e03b5_row4_col21, #T_e03b5_row4_col22, #T_e03b5_row4_col23 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_e03b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e03b5_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_e03b5_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_e03b5_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_e03b5_level0_col3" class="col_heading level0 col3" >Marital Status</th>
#       <th id="T_e03b5_level0_col4" class="col_heading level0 col4" >Parental Status</th>
#       <th id="T_e03b5_level0_col5" class="col_heading level0 col5" >Children</th>
#       <th id="T_e03b5_level0_col6" class="col_heading level0 col6" >Kidhome</th>
#       <th id="T_e03b5_level0_col7" class="col_heading level0 col7" >Teenhome</th>
#       <th id="T_e03b5_level0_col8" class="col_heading level0 col8" >Income</th>
#       <th id="T_e03b5_level0_col9" class="col_heading level0 col9" >Spent</th>
#       <th id="T_e03b5_level0_col10" class="col_heading level0 col10" >Customer Loyalty</th>
#       <th id="T_e03b5_level0_col11" class="col_heading level0 col11" >Recency</th>
#       <th id="T_e03b5_level0_col12" class="col_heading level0 col12" >Wines</th>
#       <th id="T_e03b5_level0_col13" class="col_heading level0 col13" >Fruits</th>
#       <th id="T_e03b5_level0_col14" class="col_heading level0 col14" >Meat</th>
#       <th id="T_e03b5_level0_col15" class="col_heading level0 col15" >Fish</th>
#       <th id="T_e03b5_level0_col16" class="col_heading level0 col16" >Sweets</th>
#       <th id="T_e03b5_level0_col17" class="col_heading level0 col17" >Gold</th>
#       <th id="T_e03b5_level0_col18" class="col_heading level0 col18" >Web</th>
#       <th id="T_e03b5_level0_col19" class="col_heading level0 col19" >Catalog</th>
#       <th id="T_e03b5_level0_col20" class="col_heading level0 col20" >Store</th>
#       <th id="T_e03b5_level0_col21" class="col_heading level0 col21" >Discount Purchases</th>
#       <th id="T_e03b5_level0_col22" class="col_heading level0 col22" >Total Promo</th>
#       <th id="T_e03b5_level0_col23" class="col_heading level0 col23" >NumWebVisitsMonth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e03b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e03b5_row0_col0" class="data row0 col0" >5524</td>
#       <td id="T_e03b5_row0_col1" class="data row0 col1" >58</td>
#       <td id="T_e03b5_row0_col2" class="data row0 col2" >Graduate</td>
#       <td id="T_e03b5_row0_col3" class="data row0 col3" >Alone</td>
#       <td id="T_e03b5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e03b5_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_e03b5_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_e03b5_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_e03b5_row0_col8" class="data row0 col8" >58138.000000</td>
#       <td id="T_e03b5_row0_col9" class="data row0 col9" >1617</td>
#       <td id="T_e03b5_row0_col10" class="data row0 col10" >663</td>
#       <td id="T_e03b5_row0_col11" class="data row0 col11" >58</td>
#       <td id="T_e03b5_row0_col12" class="data row0 col12" >635</td>
#       <td id="T_e03b5_row0_col13" class="data row0 col13" >88</td>
#       <td id="T_e03b5_row0_col14" class="data row0 col14" >546</td>
#       <td id="T_e03b5_row0_col15" class="data row0 col15" >172</td>
#       <td id="T_e03b5_row0_col16" class="data row0 col16" >88</td>
#       <td id="T_e03b5_row0_col17" class="data row0 col17" >88</td>
#       <td id="T_e03b5_row0_col18" class="data row0 col18" >8</td>
#       <td id="T_e03b5_row0_col19" class="data row0 col19" >10</td>
#       <td id="T_e03b5_row0_col20" class="data row0 col20" >4</td>
#       <td id="T_e03b5_row0_col21" class="data row0 col21" >3</td>
#       <td id="T_e03b5_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_e03b5_row0_col23" class="data row0 col23" >7</td>
#     </tr>
#     <tr>
#       <th id="T_e03b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e03b5_row1_col0" class="data row1 col0" >2174</td>
#       <td id="T_e03b5_row1_col1" class="data row1 col1" >61</td>
#       <td id="T_e03b5_row1_col2" class="data row1 col2" >Graduate</td>
#       <td id="T_e03b5_row1_col3" class="data row1 col3" >Alone</td>
#       <td id="T_e03b5_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_e03b5_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_e03b5_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_e03b5_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_e03b5_row1_col8" class="data row1 col8" >46344.000000</td>
#       <td id="T_e03b5_row1_col9" class="data row1 col9" >27</td>
#       <td id="T_e03b5_row1_col10" class="data row1 col10" >113</td>
#       <td id="T_e03b5_row1_col11" class="data row1 col11" >38</td>
#       <td id="T_e03b5_row1_col12" class="data row1 col12" >11</td>
#       <td id="T_e03b5_row1_col13" class="data row1 col13" >1</td>
#       <td id="T_e03b5_row1_col14" class="data row1 col14" >6</td>
#       <td id="T_e03b5_row1_col15" class="data row1 col15" >2</td>
#       <td id="T_e03b5_row1_col16" class="data row1 col16" >1</td>
#       <td id="T_e03b5_row1_col17" class="data row1 col17" >6</td>
#       <td id="T_e03b5_row1_col18" class="data row1 col18" >1</td>
#       <td id="T_e03b5_row1_col19" class="data row1 col19" >1</td>
#       <td id="T_e03b5_row1_col20" class="data row1 col20" >2</td>
#       <td id="T_e03b5_row1_col21" class="data row1 col21" >2</td>
#       <td id="T_e03b5_row1_col22" class="data row1 col22" >0</

# %%
print(f"After preprocessing, let's have a look on the summary of the dataset :")
data.describe().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After preprocessing, let's have a look on the summary of the dataset :
# <style type="text/css">
# #T_5394d_row0_col0, #T_5394d_row0_col1, #T_5394d_row0_col2, #T_5394d_row0_col3, #T_5394d_row0_col4, #T_5394d_row0_col5, #T_5394d_row0_col6, #T_5394d_row0_col7, #T_5394d_row0_col8, #T_5394d_row0_col9, #T_5394d_row0_col10, #T_5394d_row0_col11, #T_5394d_row0_col12, #T_5394d_row0_col13, #T_5394d_row0_col14, #T_5394d_row0_col15, #T_5394d_row0_col16, #T_5394d_row0_col17, #T_5394d_row0_col18, #T_5394d_row0_col19, #T_5394d_row0_col20, #T_5394d_row0_col21, #T_5394d_row1_col0, #T_5394d_row1_col1, #T_5394d_row1_col2, #T_5394d_row1_col3, #T_5394d_row1_col4, #T_5394d_row1_col5, #T_5394d_row1_col6, #T_5394d_row1_col7, #T_5394d_row1_col8, #T_5394d_row1_col9, #T_5394d_row1_col10, #T_5394d_row1_col11, #T_5394d_row1_col12, #T_5394d_row1_col13, #T_5394d_row1_col14, #T_5394d_row1_col15, #T_5394d_row1_col16, #T_5394d_row1_col17, #T_5394d_row1_col18, #T_5394d_row1_col19, #T_5394d_row1_col20, #T_5394d_row1_col21, #T_5394d_row2_col0, #T_5394d_row2_col1, #T_5394d_row2_col2, #T_5394d_row2_col3, #T_5394d_row2_col4, #T_5394d_row2_col5, #T_5394d_row2_col6, #T_5394d_row2_col7, #T_5394d_row2_col8, #T_5394d_row2_col9, #T_5394d_row2_col10, #T_5394d_row2_col11, #T_5394d_row2_col12, #T_5394d_row2_col13, #T_5394d_row2_col14, #T_5394d_row2_col15, #T_5394d_row2_col16, #T_5394d_row2_col17, #T_5394d_row2_col18, #T_5394d_row2_col19, #T_5394d_row2_col20, #T_5394d_row2_col21, #T_5394d_row3_col0, #T_5394d_row3_col1, #T_5394d_row3_col2, #T_5394d_row3_col3, #T_5394d_row3_col4, #T_5394d_row3_col5, #T_5394d_row3_col6, #T_5394d_row3_col7, #T_5394d_row3_col8, #T_5394d_row3_col9, #T_5394d_row3_col10, #T_5394d_row3_col11, #T_5394d_row3_col12, #T_5394d_row3_col13, #T_5394d_row3_col14, #T_5394d_row3_col15, #T_5394d_row3_col16, #T_5394d_row3_col17, #T_5394d_row3_col18, #T_5394d_row3_col19, #T_5394d_row3_col20, #T_5394d_row3_col21, #T_5394d_row4_col0, #T_5394d_row4_col1, #T_5394d_row4_col2, #T_5394d_row4_col3, #T_5394d_row4_col4, #T_5394d_row4_col5, #T_5394d_row4_col6, #T_5394d_row4_col7, #T_5394d_row4_col8, #T_5394d_row4_col9, #T_5394d_row4_col10, #T_5394d_row4_col11, #T_5394d_row4_col12, #T_5394d_row4_col13, #T_5394d_row4_col14, #T_5394d_row4_col15, #T_5394d_row4_col16, #T_5394d_row4_col17, #T_5394d_row4_col18, #T_5394d_row4_col19, #T_5394d_row4_col20, #T_5394d_row4_col21, #T_5394d_row5_col0, #T_5394d_row5_col1, #T_5394d_row5_col2, #T_5394d_row5_col3, #T_5394d_row5_col4, #T_5394d_row5_col5, #T_5394d_row5_col6, #T_5394d_row5_col7, #T_5394d_row5_col8, #T_5394d_row5_col9, #T_5394d_row5_col10, #T_5394d_row5_col11, #T_5394d_row5_col12, #T_5394d_row5_col13, #T_5394d_row5_col14, #T_5394d_row5_col15, #T_5394d_row5_col16, #T_5394d_row5_col17, #T_5394d_row5_col18, #T_5394d_row5_col19, #T_5394d_row5_col20, #T_5394d_row5_col21, #T_5394d_row6_col0, #T_5394d_row6_col1, #T_5394d_row6_col2, #T_5394d_row6_col3, #T_5394d_row6_col4, #T_5394d_row6_col5, #T_5394d_row6_col6, #T_5394d_row6_col7, #T_5394d_row6_col8, #T_5394d_row6_col9, #T_5394d_row6_col10, #T_5394d_row6_col11, #T_5394d_row6_col12, #T_5394d_row6_col13, #T_5394d_row6_col14, #T_5394d_row6_col15, #T_5394d_row6_col16, #T_5394d_row6_col17, #T_5394d_row6_col18, #T_5394d_row6_col19, #T_5394d_row6_col20, #T_5394d_row6_col21, #T_5394d_row7_col0, #T_5394d_row7_col1, #T_5394d_row7_col2, #T_5394d_row7_col3, #T_5394d_row7_col4, #T_5394d_row7_col5, #T_5394d_row7_col6, #T_5394d_row7_col7, #T_5394d_row7_col8, #T_5394d_row7_col9, #T_5394d_row7_col10, #T_5394d_row7_col11, #T_5394d_row7_col12, #T_5394d_row7_col13, #T_5394d_row7_col14, #T_5394d_row7_col15, #T_5394d_row7_col16, #T_5394d_row7_col17, #T_5394d_row7_col18, #T_5394d_row7_col19, #T_5394d_row7_col20, #T_5394d_row7_col21 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_5394d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5394d_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_5394d_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_5394d_level0_col2" class="col_heading level0 col2" >Parental Status</th>
#       <th id="T_5394d_level0_col3" class="col_heading level0 col3" >Children</th>
#       <th id="T_5394d_level0_col4" class="col_heading level0 col4" >Kidhome</th>
#       <th id="T_5394d_level0_col5" class="col_heading level0 col5" >Teenhome</th>
#       <th id="T_5394d_level0_col6" class="col_heading level0 col6" >Income</th>
#       <th id="T_5394d_level0_col7" class="col_heading level0 col7" >Spent</th>
#       <th id="T_5394d_level0_col8" class="col_heading level0 col8" >Customer Loyalty</th>
#       <th id="T_5394d_level0_col9" class="col_heading level0 col9" >Recency</th>
#       <th id="T_5394d_level0_col10" class="col_heading level0 col10" >Wines</th>
#       <th id="T_5394d_level0_col11" class="col_heading level0 col11" >Fruits</th>
#       <th id="T_5394d_level0_col12" class="col_heading level0 col12" >Meat</th>
#       <th id="T_5394d_level0_col13" class="col_heading level0 col13" >Fish</th>
#       <th id="T_5394d_level0_col14" class="col_heading level0 col14" >Sweets</th>
#       <th id="T_5394d_level0_col15" class="col_heading level0 col15" >Gold</th>
#       <th id="T_5394d_level0_col16" class="col_heading level0 col16" >Web</th>
#       <th id="T_5394d_level0_col17" class="col_heading level0 col17" >Catalog</th>
#       <th id="T_5394d_level0_col18" class="col_heading level0 col18" >Store</th>
#       <th id="T_5394d_level0_col19" class="col_heading level0 col19" >Discount Purchases</th>
#       <th id="T_5394d_level0_col20" class="col_heading level0 col20" >Total Promo</th>
#       <th id="T_5394d_level0_col21" class="col_heading level0 col21" >NumWebVisitsMonth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5394d_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_5394d_row0_col0" class="data row0 col0" >2212.000000</td>
#       <td id="T_5394d_row0_col1" class="data row0 col1" >2212.000000</td>
#       <td id="T_5394d_row0_col2" class="data row0 col2" >2212.000000</td>
#       <td id="T_5394d_row0_col3" class="data row0 col3" >2212.000000</td>
#       <td id="T_5394d_row0_col4" class="data row0 col4" >2212.000000</td>
#       <td id="T_5394d_row0_col5" class="data row0 col5" >2212.000000</td>
#       <td id="T_5394d_row0_col6" class="data row0 col6" >2212.000000</td>
#       <td id="T_5394d_row0_col7" class="data row0 col7" >2212.000000</td>
#       <td id="T_5394d_row0_col8" class="data row0 col8" >2212.000000</td>
#       <td id="T_5394d_row0_col9" class="data row0 col9" >2212.000000</td>
#       <td id="T_5394d_row0_col10" class="data row0 col10" >2212.000000</td>
#       <td id="T_5394d_row0_col11" class="data row0 col11" >2212.000000</td>
#       <td id="T_5394d_row0_col12" class="data row0 col12" >2212.000000</td>
#       <td id="T_5394d_row0_col13" class="data row0 col13" >2212.000000</td>
#       <td id="T_5394d_row0_col14" class="data row0 col14" >2212.000000</td>
#       <td id="T_5394d_row0_col15" class="data row0 col15" >2212.000000</td>
#       <td id="T_5394d_row0_col16" class="data row0 col16" >2212.000000</td>
#       <td id="T_5394d_row0_col17" class="data row0 col17" >2212.000000</td>
#       <td id="T_5394d_row0_col18" class="data row0 col18" >2212.000000</td>
#       <td id="T_5394d_row0_col19" class="data row0 col19" >2212.000000</td>
#       <td id="T_5394d_row0_col20" class="data row0 col20" >2212.000000</td>
#       <td id="T_5394d_row0_col21" class="data row0 col21" >2212.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5394d_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_5394d_row1_col0" class="data row1 col0" >5585.160940</td>
#       <td id="T_5394d_row1_col1" class="data row1 col1" >46.086347</td>
#       <td id="T_5394d_row1_col2" class="data row1 col2" >0.714286</td>
#       <td id="T_5394d_row1_col3" class="data row1 col3" >0.947559</td>
#       <td id="T_5394d_row1_col4" class="data row1 col4" >0.441682</td>
#       <td id="T_5394d_row1_col5" class="data row1 col5" >0.505877</td>
#       <td id="T_5394d_row1_col6" class="data row1 col6" >51958.810579</

# %%
data.describe(include=object).T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_437c0_row0_col0, #T_437c0_row0_col1, #T_437c0_row0_col2, #T_437c0_row0_col3, #T_437c0_row1_col0, #T_437c0_row1_col1, #T_437c0_row1_col2, #T_437c0_row1_col3 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_437c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_437c0_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_437c0_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_437c0_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_437c0_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_437c0_level0_row0" class="row_heading level0 row0" >Education</th>
#       <td id="T_437c0_row0_col0" class="data row0 col0" >2212</td>
#       <td id="T_437c0_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_437c0_row0_col2" class="data row0 col2" >Graduate</td>
#       <td id="T_437c0_row0_col3" class="data row0 col3" >1115</td>
#     </tr>
#     <tr>
#       <th id="T_437c0_level0_row1" class="row_heading level0 row1" >Marital Status</th>
#       <td id="T_437c0_row1_col0" class="data row1 col0" >2212</td>
#       <td id="T_437c0_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_437c0_row1_col2" class="data row1 col2" >Couple</td>
#       <td id="T_437c0_row1_col3" class="data row1 col3" >1428</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Custom Palette For Visualization

# %%
sns.set_style("white")
sns.set(rc={"axes.facecolor":"#D4C8BA","figure.facecolor":"#D4C8BA"})
sns.set_context("poster",font_scale = .7)

palette = ["#101B15","#3A392B","#7A7D58","#FFF7B6","#DD9954","#94583C","#601600"]
# palette_cmap = ["#682F2F", "#9E726F", "#D6B2B1", "#B9C0C9", "#9F8A78", "#F3AB60"]
palette_cmap = ["#B9C0C9","#D6B2B1","#F3AB60","#9F8A78","#9E726F","#682F2F"]
cluster = ["#B9C0C9","#682F2F","#7A7D58","#DD9954"]

# sns.palplot(sns.color_palette(palette))
# sns.palplot(sns.color_palette(palette_cmap))
# sns.palplot(sns.color_palette(cluster))
# plt.show()

#682F2F #585858
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# # Digging Deeper

# %%
print(f"Let's have a look on the distribution of customer's age :")
plt.subplots(figsize=(20, 8))
p = sns.histplot(data["Age"],color="#682F2F",kde=True,bins=50,alpha=1,fill=True,edgecolor="black")
p.axes.lines[0].set_color(palette[0])
p.axes.set_title("\nCustomer's Age Distribution\n",fontsize=25)
plt.ylabel("Count",fontsize=20)
plt.xlabel("\nAge",fontsize=20)
sns.despine(left=True, bottom=True)

plt.show()
# Out:
# Let's have a look on the distribution of customer's age :

# %% [markdown]
# **Insights:**
#
# * We can see it's a normal distribution of customer's age.
# * Most of the customers are from 36 to 50.

# %%
print(f"Let's have a look on the distribution of customer's income and spending :")
plt.subplots(figsize=(20, 8))
p = sns.histplot(data[["Spent","Income"]],palette=["#F3AB60","#682F2F"],kde=True,bins=30,alpha=1,fill=True,edgecolor="black")
p.axes.lines[0].set_color(palette[0])
p.axes.lines[1].set_color(palette[0])
p.axes.set_yscale("symlog")
p.axes.set_title("\nCustomer's Income-Spending Distribution\n",fontsize=25)
plt.ylabel("Count",fontsize=20)
plt.xlabel("\nAmount",fontsize=20)
sns.despine(left=True, bottom=True)

plt.show()
# Out:
# Let's have a look on the distribution of customer's income and spending :

# %% [markdown]
# **Insights:**
#
# * Most of the customers income range is in between 20000 to 80000
# * Bust almost all customers spend very few portion of their income.

# %%
print(f"Let's have a look on the customer's education :")
plt.subplots(figsize=(12, 12))

labels = "Graduate","Postgraduate","Undergraduate"
size = 0.5

wedges, texts, autotexts = plt.pie([data["Education"].value_counts()[0],
                                    data["Education"].value_counts()[1],
                                    data["Education"].value_counts()[2]],
                                    explode = (0,0,0),
                                    textprops=dict(size= 20, color= "white"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.72,
                                    radius=.9, 
                                    colors = ["#682F2F","#F3AB60","#9F8A78"], 
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "black", 
                                    linewidth = 4),
                                    startangle = 20)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1), edgecolor = "black")
plt.title("\nCustomer's Education Level",fontsize=20)
plt.show()
# Out:
# Let's have a look on the customer's education :

# %% [markdown]
# **Insights:**
#
# * Customers have three education levels : Undergraduate, Graduate, Postgraduate
# * 11.39% customers are in undergraduate level, 50.41% have completed graduation and 38.2% are on postgraduation level.

# %%
print(f"Let's have a look on the distribution of customer's income and spending on basis of education level :")

_, axes = plt.subplots(2,1,figsize=(20,16),sharex=False)
plt.tight_layout(pad=7.0)

sns.histplot(data=data,x="Income",hue="Education",multiple="stack",palette=["#682F2F","#F3AB60","#9F8A78"],ax=axes[0],kde=True,bins=50,alpha=1,fill=True,edgecolor="black")
axes[0].lines[0].set_color(palette[0])
axes[0].lines[1].set_color(palette[0])
axes[0].lines[2].set_color(palette[0])
axes[0].set_yscale("symlog")
axes[0].set_title("\nEducation Level-wise Income Distribution\n",fontsize=25)
axes[0].set_ylabel("Count",fontsize=20)
axes[0].set_xlabel("\nIncome",fontsize=20)

sns.histplot(data=data,x="Spent",hue="Education",multiple="stack",palette=["#682F2F","#F3AB60","#9F8A78"],ax=axes[1],kde=True,bins=50,alpha=1,fill=True,edgecolor="black")
axes[1].lines[0].set_color(palette[0])
axes[1].lines[1].set_color(palette[0])
axes[1].lines[2].set_color(palette[0])
axes[1].set_yscale("symlog")
axes[1].set_title("\nEducation Level-wise Spending Distribution\n",fontsize=25)
axes[1].set_ylabel("Count",fontsize=20)
axes[1].set_xlabel("\nSpending",fontsize=20)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the distribution of customer's income and spending on basis of education level :

# %% [markdown]
# **Insights:**
#
# * Most of the undergraduate level customer's income range is in between 10000 to 80000 and spending in between 0 to 1400.
# * Most of the graduate level customer's income range is in between 20000 to 85000 and spending in between 0 to 2000.
# * Most of the postgraduate level customer's income range is in between 30000 to 80000 and spending in between 0 to 2000.

# %%
print(f"Let's have a look on the distribution of customer's income and spending on basis of marital and parental status :")

_, axes = plt.subplots(2,1,figsize=(20,15),sharex=False)
plt.tight_layout(pad=6.0)

sns.swarmplot(x=data["Income"],y=data["Marital Status"],hue=data["Parental Status"],palette=["#F3AB60","#682F2F"],ax=axes[0],marker="o",size=10,alpha=1,linewidth=0.5,edgecolor="black")
axes[0].legend(["No","Yes"],title="Parent", edgecolor = "#1c1c1c",loc="center right")
axes[0].set_title("\nMarital Status-wise Income Distribution\n",fontsize=25)
axes[0].set_xlabel("\nIncome",fontsize=20)
axes[0].set_ylabel("\nMarital Status",fontsize=20)

sns.swarmplot(x=data["Spent"],y=data["Marital Status"],hue=data["Parental Status"],palette=["#F3AB60","#682F2F"],ax=axes[1],marker="o",size=10,alpha=1,linewidth=0.5,edgecolor="black")
axes[1].legend(["No","Yes"],title="Parent", edgecolor = "#1c1c1c",loc="center right")
axes[1].set_title("\nMarital Status-wise Spending Distribution\n",fontsize=25)
axes[1].set_xlabel("Spending",fontsize=20)
axes[1].set_ylabel("\nMarital Status",fontsize=20)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the distribution of customer's income and spending on basis of marital and parental status :

# %% [markdown]
# **Insights:**
#
# * Most of the customers live together.
# * Customers who live together and are parents earn much and spend much.

# %%
print(f"Let's have a look on the distribution of customer's children :")
plt.subplots(figsize=(20, 8))
p = sns.countplot(x=data["Children"],palette=["#B9C0C9","#682F2F", "#9F8A78","#F3AB60"], saturation=1,edgecolor = "#1c1c1c", linewidth = 4)
p.axes.set_yscale("linear")
p.axes.set_title("\nCustomer's Children\n",fontsize=25)
p.axes.set_ylabel("Count",fontsize=20)
p.axes.set_xlabel("\nChildren",fontsize=20)
p.axes.set_xticklabels(p.get_xticklabels(),rotation = 0)
for container in p.containers:
    p.bar_label(container,label_type="center",padding=6,size=30,color="black",rotation=0,
    bbox={"boxstyle": "round", "pad": 0.4, "facecolor": "orange", "edgecolor": "white", "linewidth" : 4, "alpha": 1})


sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the distribution of customer's children :

# %% [markdown]
# **Insights:**
#
# * 632 customers have no child.
# * Most of the customers have one child.
# * 416 customers have two child.
# * 50 customers have three child.

# %% [markdown]
# # Correlation Map

# %%
catcol = ["Education","Marital Status"]
le = LabelEncoder()
for col in catcol:
        data[col] = le.fit_transform(data[col])


plt.subplots(figsize =(20, 20))

sns.heatmap(data.drop(columns="ID").corr(), cmap = palette_cmap, square=True, cbar_kws=dict(shrink =.82), 
            annot=True, vmin=-1, vmax=1, linewidths=0.1,linecolor='white',annot_kws=dict(fontsize =12))
plt.title("Pearson Correlation Of Features\n", fontsize=25)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Insights:**
#
# * High correlation between customer's income and spending. Also high correlation between buying wine, meat and buying through catalog and stores with income and spending.
# * High correlation between buying meat and buying through catalog.

# %% [markdown]
# # Dimensionality Reduction

# %%
dataC = data.copy()
scaler = StandardScaler()
dataC = scaler.fit_transform(dataC)
scaled_data = pd.DataFrame(dataC, columns= data.columns)
print("After scaling, let's have a glimpse of the scaled dataset :")
scaled_data.head().style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# After scaling, let's have a glimpse of the scaled dataset :
# <style type="text/css">
# #T_d8335_row0_col0, #T_d8335_row0_col1, #T_d8335_row0_col2, #T_d8335_row0_col3, #T_d8335_row0_col4, #T_d8335_row0_col5, #T_d8335_row0_col6, #T_d8335_row0_col7, #T_d8335_row0_col8, #T_d8335_row0_col9, #T_d8335_row0_col10, #T_d8335_row0_col11, #T_d8335_row0_col12, #T_d8335_row0_col13, #T_d8335_row0_col14, #T_d8335_row0_col15, #T_d8335_row0_col16, #T_d8335_row0_col17, #T_d8335_row0_col18, #T_d8335_row0_col19, #T_d8335_row0_col20, #T_d8335_row0_col21, #T_d8335_row0_col22, #T_d8335_row0_col23, #T_d8335_row1_col0, #T_d8335_row1_col1, #T_d8335_row1_col2, #T_d8335_row1_col3, #T_d8335_row1_col4, #T_d8335_row1_col5, #T_d8335_row1_col6, #T_d8335_row1_col7, #T_d8335_row1_col8, #T_d8335_row1_col9, #T_d8335_row1_col10, #T_d8335_row1_col11, #T_d8335_row1_col12, #T_d8335_row1_col13, #T_d8335_row1_col14, #T_d8335_row1_col15, #T_d8335_row1_col16, #T_d8335_row1_col17, #T_d8335_row1_col18, #T_d8335_row1_col19, #T_d8335_row1_col20, #T_d8335_row1_col21, #T_d8335_row1_col22, #T_d8335_row1_col23, #T_d8335_row2_col0, #T_d8335_row2_col1, #T_d8335_row2_col2, #T_d8335_row2_col3, #T_d8335_row2_col4, #T_d8335_row2_col5, #T_d8335_row2_col6, #T_d8335_row2_col7, #T_d8335_row2_col8, #T_d8335_row2_col9, #T_d8335_row2_col10, #T_d8335_row2_col11, #T_d8335_row2_col12, #T_d8335_row2_col13, #T_d8335_row2_col14, #T_d8335_row2_col15, #T_d8335_row2_col16, #T_d8335_row2_col17, #T_d8335_row2_col18, #T_d8335_row2_col19, #T_d8335_row2_col20, #T_d8335_row2_col21, #T_d8335_row2_col22, #T_d8335_row2_col23, #T_d8335_row3_col0, #T_d8335_row3_col1, #T_d8335_row3_col2, #T_d8335_row3_col3, #T_d8335_row3_col4, #T_d8335_row3_col5, #T_d8335_row3_col6, #T_d8335_row3_col7, #T_d8335_row3_col8, #T_d8335_row3_col9, #T_d8335_row3_col10, #T_d8335_row3_col11, #T_d8335_row3_col12, #T_d8335_row3_col13, #T_d8335_row3_col14, #T_d8335_row3_col15, #T_d8335_row3_col16, #T_d8335_row3_col17, #T_d8335_row3_col18, #T_d8335_row3_col19, #T_d8335_row3_col20, #T_d8335_row3_col21, #T_d8335_row3_col22, #T_d8335_row3_col23, #T_d8335_row4_col0, #T_d8335_row4_col1, #T_d8335_row4_col2, #T_d8335_row4_col3, #T_d8335_row4_col4, #T_d8335_row4_col5, #T_d8335_row4_col6, #T_d8335_row4_col7, #T_d8335_row4_col8, #T_d8335_row4_col9, #T_d8335_row4_col10, #T_d8335_row4_col11, #T_d8335_row4_col12, #T_d8335_row4_col13, #T_d8335_row4_col14, #T_d8335_row4_col15, #T_d8335_row4_col16, #T_d8335_row4_col17, #T_d8335_row4_col18, #T_d8335_row4_col19, #T_d8335_row4_col20, #T_d8335_row4_col21, #T_d8335_row4_col22, #T_d8335_row4_col23 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_d8335">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8335_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_d8335_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_d8335_level0_col2" class="col_heading level0 col2" >Education</th>
#       <th id="T_d8335_level0_col3" class="col_heading level0 col3" >Marital Status</th>
#       <th id="T_d8335_level0_col4" class="col_heading level0 col4" >Parental Status</th>
#       <th id="T_d8335_level0_col5" class="col_heading level0 col5" >Children</th>
#       <th id="T_d8335_level0_col6" class="col_heading level0 col6" >Kidhome</th>
#       <th id="T_d8335_level0_col7" class="col_heading level0 col7" >Teenhome</th>
#       <th id="T_d8335_level0_col8" class="col_heading level0 col8" >Income</th>
#       <th id="T_d8335_level0_col9" class="col_heading level0 col9" >Spent</th>
#       <th id="T_d8335_level0_col10" class="col_heading level0 col10" >Customer Loyalty</th>
#       <th id="T_d8335_level0_col11" class="col_heading level0 col11" >Recency</th>
#       <th id="T_d8335_level0_col12" class="col_heading level0 col12" >Wines</th>
#       <th id="T_d8335_level0_col13" class="col_heading level0 col13" >Fruits</th>
#       <th id="T_d8335_level0_col14" class="col_heading level0 col14" >Meat</th>
#       <th id="T_d8335_level0_col15" class="col_heading level0 col15" >Fish</th>
#       <th id="T_d8335_level0_col16" class="col_heading level0 col16" >Sweets</th>
#       <th id="T_d8335_level0_col17" class="col_heading level0 col17" >Gold</th>
#       <th id="T_d8335_level0_col18" class="col_heading level0 col18" >Web</th>
#       <th id="T_d8335_level0_col19" class="col_heading level0 col19" >Catalog</th>
#       <th id="T_d8335_level0_col20" class="col_heading level0 col20" >Store</th>
#       <th id="T_d8335_level0_col21" class="col_heading level0 col21" >Discount Purchases</th>
#       <th id="T_d8335_level0_col22" class="col_heading level0 col22" >Total Promo</th>
#       <th id="T_d8335_level0_col23" class="col_heading level0 col23" >NumWebVisitsMonth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8335_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8335_row0_col0" class="data row0 col0" >-0.018837</td>
#       <td id="T_d8335_row0_col1" class="data row0 col1" >1.018352</td>
#       <td id="T_d8335_row0_col2" class="data row0 col2" >-0.893586</td>
#       <td id="T_d8335_row0_col3" class="data row0 col3" >-1.349603</td>
#       <td id="T_d8335_row0_col4" class="data row0 col4" >-1.581139</td>
#       <td id="T_d8335_row0_col5" class="data row0 col5" >-1.264598</td>
#       <td id="T_d8335_row0_col6" class="data row0 col6" >-0.822754</td>
#       <td id="T_d8335_row0_col7" class="data row0 col7" >-0.929699</td>
#       <td id="T_d8335_row0_col8" class="data row0 col8" >0.287105</td>
#       <td id="T_d8335_row0_col9" class="data row0 col9" >1.676245</td>
#       <td id="T_d8335_row0_col10" class="data row0 col10" >1.527721</td>
#       <td id="T_d8335_row0_col11" class="data row0 col11" >0.310353</td>
#       <td id="T_d8335_row0_col12" class="data row0 col12" >0.977660</td>
#       <td id="T_d8335_row0_col13" class="data row0 col13" >1.552041</td>
#       <td id="T_d8335_row0_col14" class="data row0 col14" >1.690293</td>
#       <td id="T_d8335_row0_col15" class="data row0 col15" >2.453472</td>
#       <td id="T_d8335_row0_col16" class="data row0 col16" >1.483713</td>
#       <td id="T_d8335_row0_col17" class="data row0 col17" >0.852576</td>
#       <td id="T_d8335_row0_col18" class="data row0 col18" >1.426865</td>
#       <td id="T_d8335_row0_col19" class="data row0 col19" >2.503607</td>
#       <td id="T_d8335_row0_col20" class="data row0 col20" >-0.555814</td>
#       <td id="T_d8335_row0_col21" class="data row0 col21" >0.351030</td>
#       <td id="T_d8335_row0_col22" class="data row0 col22" >-0.439160</td>
#       <td id="T_d8335_row0_col23" class="data row0 col23" >0.692181</td>
#     </tr>
#     <tr>
#       <th id="T_d8335_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d8335_row1_col0" class="data row1 col0" >-1.050626</td>
#       <td id="T_d8335_row1_col1" class="data row1 col1" >1.274785</td>
#       <td id="T_d8335_row1_col2" class="data row1 col2" >-0.893586</td>
#       <td id="T_d8335_row1_col3" class="data row1 col3" >-1.349603</td>
#       <td id="T_d8335_row1_col4" class="data row1 col4" >0.632456</td>
#       <td id="T_d8335_row1_col5" class="data row1 col5" >1.404572</td>
#       <td id="T_d8335_row1_col6" class="data row1 col6" >1.040021</td>
#       <td id="T_d8335_row1_col7" class="data row1 col7" >0.908097</td>
#       <td id="T_d8335_row1_col8" class="data row1 col8" >-0.260882</td>
#       <td id="T_d8335_row1_col9" class="data row1 col9" >-0.963297</td>
#       <td id="T_d8335_row1_col10" class="data row1 col10" >-1.189011</td>
#       <td id="T_d8335_row1_col11" class="data row1 col11" >-0.380813</td>
#       <td id="T_d8335_row1_col12" class="data row1 col12" >-0.872618</td>
#       <td id="T_d8335_row1_col13" class="data row1 col13" >-0.637461</td>
#       <td id="T_d8335_row1_col14" class="data row1 col14" >-0.718230</td>
#       <td id="T_d8335_row1_col15" class="data row1 col15" >-0.651004</td>
#       <td id="T_d8335_row1_col16" class="data row1 col16" >-0.634019</td>
#       <td id="T_d8335_row1_col17" class="data row1 col17" >-0.733642</td>
#       <td id="T_d8335_row1_col18" class="data row1 col18" >-1.126420</td>
#       <td

# %%
scaled_dataC = scaled_data.copy()
pca = PCA(n_components = 3,random_state = 42)
scaled_dataC = pca.fit_transform(scaled_dataC)
pca_data = pd.DataFrame(scaled_dataC, columns=["col1","col2", "col3"])

print("Let's have a glimpse of the PCA transformed dataset :")
pca_data.head(15).T.style.set_properties(**{"background-color": "#682F2F","color":"#e9c46a","border": "1.5px solid black"})
# Out:
# Let's have a glimpse of the PCA transformed dataset :
# <style type="text/css">
# #T_9999f_row0_col0, #T_9999f_row0_col1, #T_9999f_row0_col2, #T_9999f_row0_col3, #T_9999f_row0_col4, #T_9999f_row0_col5, #T_9999f_row0_col6, #T_9999f_row0_col7, #T_9999f_row0_col8, #T_9999f_row0_col9, #T_9999f_row0_col10, #T_9999f_row0_col11, #T_9999f_row0_col12, #T_9999f_row0_col13, #T_9999f_row0_col14, #T_9999f_row1_col0, #T_9999f_row1_col1, #T_9999f_row1_col2, #T_9999f_row1_col3, #T_9999f_row1_col4, #T_9999f_row1_col5, #T_9999f_row1_col6, #T_9999f_row1_col7, #T_9999f_row1_col8, #T_9999f_row1_col9, #T_9999f_row1_col10, #T_9999f_row1_col11, #T_9999f_row1_col12, #T_9999f_row1_col13, #T_9999f_row1_col14, #T_9999f_row2_col0, #T_9999f_row2_col1, #T_9999f_row2_col2, #T_9999f_row2_col3, #T_9999f_row2_col4, #T_9999f_row2_col5, #T_9999f_row2_col6, #T_9999f_row2_col7, #T_9999f_row2_col8, #T_9999f_row2_col9, #T_9999f_row2_col10, #T_9999f_row2_col11, #T_9999f_row2_col12, #T_9999f_row2_col13, #T_9999f_row2_col14 {
#   background-color: #682F2F;
#   color: #e9c46a;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_9999f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9999f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_9999f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_9999f_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_9999f_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_9999f_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_9999f_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_9999f_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_9999f_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_9999f_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_9999f_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_9999f_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_9999f_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_9999f_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_9999f_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_9999f_level0_col14" class="col_heading level0 col14" >14</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9999f_level0_row0" class="row_heading level0 row0" >col1</th>
#       <td id="T_9999f_row0_col0" class="data row0 col0" >4.568310</td>
#       <td id="T_9999f_row0_col1" class="data row0 col1" >-2.875395</td>
#       <td id="T_9999f_row0_col2" class="data row0 col2" >2.413477</td>
#       <td id="T_9999f_row0_col3" class="data row0 col3" >-2.690235</td>
#       <td id="T_9999f_row0_col4" class="data row0 col4" >-0.613424</td>
#       <td id="T_9999f_row0_col5" class="data row0 col5" >0.564686</td>
#       <td id="T_9999f_row0_col6" class="data row0 col6" >0.494467</td>
#       <td id="T_9999f_row0_col7" class="data row0 col7" >-2.432465</td>
#       <td id="T_9999f_row0_col8" class="data row0 col8" >-3.000794</td>
#       <td id="T_9999f_row0_col9" class="data row0 col9" >-4.822590</td>
#       <td id="T_9999f_row0_col10" class="data row0 col10" >-1.769695</td>
#       <td id="T_9999f_row0_col11" class="data row0 col11" >3.778201</td>
#       <td id="T_9999f_row0_col12" class="data row0 col12" >-1.836093</td>
#       <td id="T_9999f_row0_col13" class="data row0 col13" >-1.737553</td>
#       <td id="T_9999f_row0_col14" class="data row0 col14" >4.303172</td>
#     </tr>
#     <tr>
#       <th id="T_9999f_level0_row1" class="row_heading level0 row1" >col2</th>
#       <td id="T_9999f_row1_col0" class="data row1 col0" >0.162165</td>
#       <td id="T_9999f_row1_col1" class="data row1 col1" >0.219220</td>
#       <td id="T_9999f_row1_col2" class="data row1 col2" >-0.843289</td>
#       <td id="T_9999f_row1_col3" class="data row1 col3" >-1.541448</td>
#       <td id="T_9999f_row1_col4" class="data row1 col4" >-0.046576</td>
#       <td id="T_9999f_row1_col5" class="data row1 col5" >1.247157</td>
#       <td id="T_9999f_row1_col6" class="data row1 col6" >1.589400</td>
#       <td id="T_9999f_row1_col7" class="data row1 col7" >-0.902853</td>
#       <td id="T_9999f_row1_col8" class="data row1 col8" >-1.226579</td>
#       <td id="T_9999f_row1_col9" class="data row1 col9" >0.588506</td>
#       <td id="T_9999f_row1_col10" class="data row1 col10" >-2.576028</td>
#       <td id="T_9999f_row1_col11" class="data row1 col11" >-1.924905</td>
#       <td id="T_9999f_row1_col12" class="data row1 col12" >1.565116</td>
#       <td id="T_9999f_row1_col13" class="data row1 col13" >-2.737951</td>
#       <td id="T_9999f_row1_col14" class="data row1 col14" >0.204356</td>
#     </tr>
#     <tr>
#       <th id="T_9999f_level0_row2" class="row_heading level0 row2" >col3</th>
#       <td id="T_9999f_row2_col0" class="data row2 col0" >2.084677</td>
#       <td id="T_9999f_row2_col1" class="data row2 col1" >-2.006241</td>
#       <td id="T_9999f_row2_col2" class="data row2 col2" >-0.184249</td>
#       <td id="T_9999f_row2_col3" class="data row2 col3" >0.168357</td>
#       <td id="T_9999f_row2_col4" class="data row2 col4" >0.451250</td>
#       <td id="T_9999f_row2_col5" class="data row2 col5" >-0.776980</td>
#       <td id="T_9999f_row2_col6" class="data row2 col6" >0.863670</td>
#       <td id="T_9999f_row2_col7" class="data row2 col7" >1.491573</td>
#       <td id="T_9999f_row2_col8" class="data row2 col8" >0.964137</td>
#       <td id="T_9999f_row2_col9" class="data row2 col9" >0.739021</td>
#       <td id="T_9999f_row2_col10" class="data row2 col10" >1.717557</td>
#       <td id="T_9999f_row2_col11" class="data row2 col11" >-0.760807</td>
#       <td id="T_9999f_row2_col12" class="data row2 col12" >-1.264763</td>
#       <td id="T_9999f_row2_col13" class="data row2 col13" >1.905645</td>
#       <td id="T_9999f_row2_col14" class="data row2 col14" >-0.094209</td>
#     </tr>
#   </tbody>
# </table>

# %%
x = pca_data["col1"]
y = pca_data["col2"]
z = pca_data["col3"]

print(f"Let's have a look on the dataset after dimensionality reduction :")

fig = go.Figure(data = [go.Scatter3d(x=x, y=y, z=z,mode='markers',
                marker = dict(size=10, color="#682F2F", opacity=0.8))])
fig.update_layout(title=dict(text= "Dataset After Diemsionality Reduction[3D Projection]",
                             y=0.97,x=0.5,xanchor= "center",yanchor= "top",font_color="black"),
                  scene=dict(xaxis = dict(title="col1",backgroundcolor="#D4C8BA",showbackground=True,showgrid=True, gridwidth=2, gridcolor='white',zerolinecolor="white"),
                             yaxis = dict(title="col2",backgroundcolor="#D4C8BA",showbackground=True,showgrid=True, gridwidth=2, gridcolor='white',zerolinecolor="white"),
                             zaxis = dict(title="col3",backgroundcolor="#D4C8BA",showbackground=True,showgrid=True, gridwidth=2, gridcolor='white',zerolinecolor="white")),
                  margin=dict(l=0, r=0, b=0, t=0),paper_bgcolor="#D4C8BA")
fig.show()
# Out:
# Let's have a look on the dataset after dimensionality reduction :
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="76db33a1-ae3b-40fe-8576-ad4cae59b825" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("76db33a1-ae3b-40fe-8576-ad4cae59b825")) {                    Plotly.newPlot(                        "76db33a1-ae3b-40fe-8576-ad4cae59b825",                        [{"marker":{"color":"#682F2F","opacity":0.8,"size":10},"mode":"markers","x":{"dtype":"f8","bdata":"O0P9CfNFEkAFxizkzgAHwCxJVS\u002fNTgNA4zg8H5qFBcBs2oViK6Hjv3yalfPoEeI\u002fcvsMbVml3z\u002fbmP4ssHUDwH8BCDegAQjAgIWgAVVKE8ANrTEgrFD8v5CFr3PBOQ5AJv0lIqNg\u002fb8odS7cA837vxeLusRyNhFADR91jLYpCMBoGXIig3DRP5Iw4dio5gxAvTdhZ4m8AMD6QXAeLniXv4Ov1ekWMwNArL18mcKcvj+1jBKDmxOwP\u002fI092yrUu6\u002fRXsXYSET9b88zglptL4BwB5xfzHXL\u002f6\u002fYF+QzjRNFEAMGuOmF7D6v51q+2sHK9w\u002fs6FTZ0pf+r\u002fYSUNZQmX3v9jjkyVLOQdAeSVTVhk6B8BnSduNTUrzP03ql7eUtgXA7oi1wurqAMBXnOBdiOEGQNYdSAldHAxA0BV4zh16CMBpDjcVVtkDwPbPZi8XGwjAuBhA2Mk5EUAJK\u002f52SLD4v80O52m3xwbAhZJIpGt\u002f5j\u002fCV3WbxiPkPx3Y2qFJMBVA+\u002fqtiL4jBMBiXuWIVPIXQJpohBaMBNu\u002f7AUB6gn4GkCL+8nhN30NQAeOqdieOgTACKc2fPZj5r9gLS2xGo8QQN6dg8gmQdi\u002fu76b8bgd8D8331T6xb6yP8Yzx57lzQhAEBeClXRtBsD1nzehWqgLwIwSJ+T09Q1A7KXjKXTw8j8K6oDNx1TmP6QjRfFStgxAugyIA86ZAECLCMMvJInpvzM4OzxibuW\u002fagvV5H2QBcDMNskxL4wRQJWsTQM9rxhAN4G5Dj4U97\u002f1YiKzlHzwP91tajvhVQPA8GPl9Xj7B8BVBMZo22wGwG2wXI\u002f7Gdw\u002fB4gSGdGCC0Bg4ZmsNPsIwOkDaDtx3QXALNxNBFq65b9S9AfoFQ8TQPbOISB8EfG\u002fvBySovYDBsB8Loqk\u002f2kFwPC73v6ygwXAVEQankbUqL\u002fhXxg4nHMHwIkIsXx8VQ9ADQzPaJw\u002f7D9NnP6qO6QCwJo2kvmf0gLAsmnT05WcEEAFEX82m8UGQGBxBgu7eQ1AGwzZBV6eBsBxUacHfnUEwMVaJXmRhPg\u002f+GB26VUCAsAdtiohu4oHQH5vRoZfSwNAV\u002f9yGrWXCEDI1wC4c1DCv13mTfsCtQhAQZ4AIVNY77\u002fAWdAz+LgEwEnnxqROyxVAGz76+SCMxT\u002fgOjkpFVIHwHG1dN6nNgbA1oaZWUIJ6z\u002fpdHD4NcwDwDTlFDp2Ag\u002fAJASrI8A\u002fBsBCM0o+k3IUQK4Fu6WJNQBAkmgYLLRDFkDXU698Nf4FwDJK7UUYrdC\u002fwQ4Vx4Oi4T+BpvzMngLyv99hSHtaTARAQotbFTESBMAgE3Qgx38MQLVwUkl5wQnASMXzFavpDsBbEFq0bMYGwKsTbpsSXQnAUeaTsFdjFEByqM3CQkPeP5IXYjBI0RBACcfef+xz8D\u002fB4319TuLyv6pgZRHA4de\u002fAJqE7RhbBMBhMcaoKr4HwA0ma1xAdwzAUPdNRMj02b+eSQsfE5nbv+XdjOh7cNC\u002f4wqKHXE56r81LDQjIC0DwKpQDhM8LvM\u002fNHyvO4vbCkCwkCkoFZHzvyxtf9aSsQnAYpZ52AhD8L9V6QVWG6oOQKELatM7qRDAW2rdsMYqDEBRiN0roY8GwFQDnKUtMAVAo7VGXYPnD0BY\u002fihvIVoMwAZZADs10v4\u002fwrWQxEJryT+SuAT\u002frWEQQLZKsCawSAbAWHIvP3g3CsAZTVYeAIYGwLI8Kd8gTwbAQ4dLLSIsBcCugc\u002fVTlr1v4ul6q7xdQ5AF8At8vpDE0B5DNOswBAKwM64OwkDAg3Awg0Qwf5QD0Cy119QetH4v1V+W\u002ffhDAfArRm7yMawCEA0C9R4C9gFwLzEORKqOva\u002fJ2i73XcICMC3oOqJz+cCwGg5vlrIZsU\u002f\u002ft3qYHA0EkAqIRWgvikIwMelfFdoAQPAMEUAM1XLEUCthBxzoj4EwEoAIpgGxf6\u002feoclpyyfC8B0aABgzPP\u002fP+xm6ewZPBJA+Ls011juEUAxXd9cIgcCwASB+59E0qg\u002fwIkUw+VFEkCbKMRadtABQCq6jRGbVRVAHMF6pxepCcByd8uM3IH2v4CE5tV0KwbAtN8jRJrr\u002fL8Z+iHMWIYBwHBqM5\u002fpiwlArmU5TM4I779Q0fS73wQKQGmKk2IT5ATA82uYCYRO+r8su\u002ftyllYPQAZK70OSrvK\u002fH6YDEHCUEMBDqWWAvv0RQFzHYAkP4\u002fW\u002fKGOeFWjY+D9CbU7qoXf\u002fv88SfmqX7gRAK2QSYEunyz8qsXYjDiIEwK70bcNXcP8\u002f7LHLNas4AsCf6R5X4xfRv+cp1hob8t0\u002f9KLGQuAEEUDwcaHPBwAJwPfb7n++Mf6\u002fzOQ4PSieCECgx9yXZhkHwIRnxBlghPW\u002fypFjOZwK\u002fT8Kq0uzyWgFwKEL5Ad0qAjAXuUb7Ncy5T9A6xcaJRMHwFGpx1vjDBhASN0HHhhvAUAF219XuScJwLNx8NporhZA67ttkEd79T8kBmqe0doKwGW87fiDGQNAPq9wNs2sA0AUs86sAucWQFJoR6wz9gZAuh384Uq+BsA2bISJgZEGwB8owAVmaBpAWSIy1wMG279Fmq3pYEvpP9wLV6wZXAbA\u002fdpF85Rd6j\u002fKCMcwkvbfv9yl0EBToAjAW6t2Zv2REMAZFD8kJhMGwDbiMpJf4tw\u002f4gTPsh0b+r9XSuvicmoIwKo52USdKQPAYwuyIVRxB8DarHYZDzkWQBdCXDvqbgPAm9VXczHNDUDjwJgmY4wEwM5ud85DCwxAb9YVq38JBMATtp52uFv0v7s8Ousd6gjAfFb4iHiKB8AyoahkKiLmP06Tv+Eycg9AFeFq8TzJBkA1f7f4jXIIQHq+vwB62vA\u002f6HMSeAiBA8C3Sn\u002f7WUPRv4z8STo7NtE\u002fFusjTA3Aqz9bBF5+dD8IwDvEad1GWgTAV+NKkwLaDkBGp26\u002fm7bgP9V+mPdGIBZAVfoADcbQ0L\u002fZHz5uLJP ...

# %% [markdown]
# # Customer Segmentation

# %%
print("Elbow Method for determining the number of clusters :")
_, axes = plt.subplots(figsize=(20,8))

elbow = KElbowVisualizer(KMeans(), k=10, timings=False, locate_elbow=True, size=(1260,450))
elbow.fit(pca_data)

axes.set_title("\nDistortion Score Elbow For KMeans Clustering\n",fontsize=25)
axes.set_xlabel("\nK",fontsize=20)
axes.set_ylabel("\nDistortion Score",fontsize=20)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Elbow Method for determining the number of clusters :

# %% [markdown]
# **Insights:**
#
# * We will use **k = 4**, thus there will be **four clusters** in our dataset.
# * We will use **KMeans Algorithm** for clustering.

# %%
km = KMeans(n_clusters = 4,random_state = 42)
# ac = AgglomerativeClustering(n_clusters=4)

y_km = km.fit_predict(pca_data)
pca_data["Clusters"] = y_km
data["Clusters"]= y_km

# %%
print("Let's have a look on the customers quantity distribution after clustering :")

plt.subplots(figsize=(20, 8))
p = sns.countplot(x=data["Clusters"],palette=["#B9C0C9","#682F2F", "#9F8A78","#F3AB60"], saturation=1,edgecolor = "#1c1c1c", linewidth = 4)
p.axes.set_yscale("linear")
p.axes.set_title("\nCustomer's Clusters\n",fontsize=25)
p.axes.set_ylabel("Count",fontsize=20)
p.axes.set_xlabel("\nCluster",fontsize=20)
p.axes.set_xticklabels(p.get_xticklabels(),rotation = 0)
for container in p.containers:
    p.bar_label(container,label_type="center",padding=6,size=30,color="black",rotation=0,
    bbox={"boxstyle": "round", "pad": 0.4, "facecolor": "orange", "edgecolor": "white", "linewidth" : 4, "alpha": 1})


sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the customers quantity distribution after clustering :

# %% [markdown]
# **Insights:**
#
# * Cluster 0 has 508 customers.
# * Cluster 1 has the highest amount of 599 customers.
# * Cluster 2 has 577 customers.
# * Cluster 3 has 531 customers.

# %%
print(f"Let's have a look on the dataset after clustering :")

fig = go.Figure(data = [go.Scatter3d(x=x, y=y, z=z,mode='markers',
                marker = dict(size=10, color=pca_data["Clusters"],colorscale=["#B9C0C9","#682F2F", "#9F8A78","#F3AB60"], opacity=1))])
fig.update_layout(title=dict(text= "Dataset After Clustering[3D Projection]",
                             y=0.97,x=0.5,xanchor= "center",yanchor= "top",font_color="black"),
                  scene=dict(xaxis = dict(title="col1",backgroundcolor="#D4C8BA",showbackground=True,showgrid=True, gridwidth=2, gridcolor='white',zerolinecolor="white"),
                             yaxis = dict(title="col2",backgroundcolor="#D4C8BA",showbackground=True,showgrid=True, gridwidth=2, gridcolor='white',zerolinecolor="white"),
                             zaxis = dict(title="col3",backgroundcolor="#D4C8BA",showbackground=True,showgrid=True, gridwidth=2, gridcolor='white',zerolinecolor="white")),
                  margin=dict(l=0, r=0, b=0, t=0),paper_bgcolor="#D4C8BA")
fig.show()
# Out:
# Let's have a look on the dataset after clustering :
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="545da7ff-c9fc-4579-a870-e98157de34df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("545da7ff-c9fc-4579-a870-e98157de34df")) {                    Plotly.newPlot(                        "545da7ff-c9fc-4579-a870-e98157de34df",                        [{"marker":{"color":{"dtype":"i4","bdata":"..."},"colorscale":[[0.0,"#B9C0C9"],[0.3333333333333333,"#682F2F"],[0.6666666666666666,"#9F8A78"],[1.0,"#F3AB60"]],"opacity":1,"size":10},"mode":"markers","x":{"dtype":"f8","bdata":"O0P9CfNFEkAFxizkzgAHwCxJVS\u002fNTgNA4zg8H5qFBcBs2oViK6Hjv3yalfPoEeI\u002fcvsMbVml3z\u002fbmP4ssHUDwH8BCDegAQjAgIWgAVVKE8ANrTEgrFD8v5CFr3PBOQ5AJv0lIqNg\u002fb8odS7cA837vxeLusRyNhFADR91jLYpCMBoGXIig3DRP5Iw4dio5gxAvTdhZ4m8AMD6QXAeLniXv4Ov1ekWMwNArL18mcKcvj+1jBKDmxOwP\u002fI092yrUu6\u002fRXsXYSET9b88zglptL4BwB5xfzHXL\u002f6\u002fYF+QzjRNFEAMGuOmF7D6v51q+2sHK9w\u002fs6FTZ0pf+r\u002fYSUNZQmX3v9jjkyVLOQdAeSVTVhk6B8BnSduNTUrzP03ql7eUtgXA7oi1wurqAMBXnOBdiOEGQNYdSAldHAxA0BV4zh16CMBpDjcVVtkDwPbPZi8XGwjAuBhA2Mk5EUAJK\u002f52SLD4v80O52m3xwbAhZJIpGt\u002f5j\u002fCV3WbxiPkPx3Y2qFJMBVA+\u002fqtiL4jBMBiXuWIVPIXQJpohBaMBNu\u002f7AUB6gn4GkCL+8nhN30NQAeOqdieOgTACKc2fPZj5r9gLS2xGo8QQN6dg8gmQdi\u002fu76b8bgd8D8331T6xb6yP8Yzx57lzQhAEBeClXRtBsD1nzehWqgLwIwSJ+T09Q1A7KXjKXTw8j8K6oDNx1TmP6QjRfFStgxAugyIA86ZAECLCMMvJInpvzM4OzxibuW\u002fagvV5H2QBcDMNskxL4wRQJWsTQM9rxhAN4G5Dj4U97\u002f1YiKzlHzwP91tajvhVQPA8GPl9Xj7B8BVBMZo22wGwG2wXI\u002f7Gdw\u002fB4gSGdGCC0Bg4ZmsNPsIwOkDaDtx3QXALNxNBFq65b9S9AfoFQ8TQPbOISB8EfG\u002fvBySovYDBsB8Loqk\u002f2kFwPC73v6ygwXAVEQankbUqL\u002fhXxg4nHMHwIkIsXx8VQ9ADQzPaJw\u002f7D9NnP6qO6QCwJo2kvmf0gLAsmnT05WcEEAFEX82m8UGQGBxBgu7eQ1AGwzZBV6eBsBxUacHfnUEwMVaJXmRhPg\u002f+GB26VUCAsAdtiohu4oHQH5vRoZfSwNAV\u002f9yGrWXCEDI1wC4c1DCv13mTfsCtQhAQZ4AIVNY77\u002fAWdAz+LgEwEnnxqROyxVAGz76+SCMxT\u002fgOjkpFVIHwHG1dN6nNgbA1oaZWUIJ6z\u002fpdHD4NcwDwDTlFDp2Ag\u002fAJASrI8A\u002fBsBCM0o+k3IUQK4Fu6WJNQBAkmgYLLRDFkDXU698Nf4FwDJK7UUYrdC\u002fwQ4Vx4Oi4T+BpvzMngLyv99hSHtaTARAQotbFTESBMAgE3Qgx38MQLVwUkl5wQnASMXzFavpDsBbEFq0bMYGwKsTbpsSXQnAUeaTsFdjFEByqM3CQkPeP5IXYjBI0RBACcfef+xz8D\u002fB4319TuLyv6pgZRHA4de\u002fAJqE7RhbBMBhMcaoKr4HwA0ma1xAdwzAUPdNRMj02b+eSQsfE5nbv+XdjOh7cNC\u002f4wqKHXE56r81LDQjIC0DwKpQDhM8LvM\u002fNHyvO4vbCkCwkCkoFZHzvyxtf9aSsQnAYpZ52AhD8L9V6QVWG6oOQKELatM7qRDAW2rdsMYqDEBRiN0roY8GwFQDnKUtMAVAo7VGXYPnD0BY\u002fihvIVoMwAZZADs10v4\u002fwrWQxEJryT+SuAT\u002frWEQQLZKsCawSAbAWHIvP3g3CsAZTVYeAIYGwLI8Kd8gTwbAQ4dLLSIsBcCugc\u002fVTlr1v4ul6q7xdQ5AF8At8vpDE0B5DNOswBAKwM64OwkDAg3Awg0Qwf5QD0Cy119QetH4v1V+W\u002ffhDAfArRm7yMawCEA0C9R4C9gFwLzEORKqOva\u002fJ2i73XcICMC3oOqJz+cCwGg5vlrIZsU\u002f\u002ft3qYHA0EkAqIRWgvikIwMelfFdoAQPAMEUAM1XLEUCthBxzoj4EwEoAIpgGxf6\u002feoclpyyfC8B0aABgzPP\u002fP+xm6ewZPBJA+Ls011juEUAxXd9cIgcCwASB+59E0qg\u002fwIkUw+VFEkCbKMRadtABQCq6jRGbVRVAHMF6pxepCcByd8uM3IH2v4CE5tV0KwbAtN8jRJrr\u002fL8Z+iHMWIYBwHBqM5\u002fpiwlArmU5TM4I779Q0fS73wQKQGmKk2IT5ATA82uYCYRO+r8su\u002ftyllYPQAZK70OSrvK\u002fH6YDEHCUEMBDqWWAvv0RQFzHYAkP4\u002fW\u002fKGOeFWjY+D9CbU7qoXf\u002fv88SfmqX7gRAK2QSYEunyz8qsXYjDiIEwK70bcNXcP8\u002f7LHLNas4AsCf6R5X4xfRv+cp1hob8t0\u002f9KLGQuAEEUDwcaHPBwAJwPfb7n++Mf6\u002fzOQ4PSieCECgx9yXZhkHwIRnxBlghPW\u002fypFjOZwK\u002fT8Kq0uzyWgFwKEL5Ad0qAjAXuUb7Ncy5T9A6xcaJRMHwFGpx1vjDBhASN0HHhhvAUAF219XuScJwLNx8NporhZA67ttkEd79T8kBmqe0doKwGW87fiDGQNAPq9wNs2sA0AUs86sAucWQFJoR6wz9gZAuh384Uq+BsA2bISJgZEGwB8owAVmaBpAWSIy1wMG279Fmq3pYEvpP9wLV6wZXAbA\u002fdpF85Rd6j\u002fKCMcwkvbfv9yl0EBToAjAW6t2Zv2REMAZFD8kJhMGwDbiMpJf4tw\u002f4gTPsh0b+r9XSuvicmoIwKo52USdKQPAYwuyIVRxB8DarHYZDzkWQBdCXDvqbgPAm9VXczHNDUDjwJgmY4wEwM5ud85DCwxAb9YVq38JBMATtp52uFv0v7s8Ousd6gjAfFb4iHiKB8AyoahkKiLmP06Tv+Eycg9AFeFq8TzJBkA1f7f4jXIIQHq+vwB62vA\u002f6HMSeAiBA ...

# %%
print(f"Let's have a look on the characteristics of the clusters on the basis of income and spending :")

_, axes = plt.subplots(figsize=(20,8))
sns.scatterplot(x=data["Spent"],y=data["Income"],hue=data["Clusters"],palette=["#B9C0C9","#682F2F", "#9F8A78","#F3AB60"],sizes=60, alpha=1,edgecolor = "#1c1c1c", linewidth = 1)
axes.set_title("\nIncome-Spending Basis Clustering Profile\n",fontsize=25)
axes.set_ylabel("Income",fontsize=20)
axes.set_xlabel("\nSpending",fontsize=20)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the characteristics of the clusters on the basis of income and spending :

# %% [markdown]
# **Insights:**
#
# * Most of the cluster 0 customers income range is in between 30000 to 100000 and spending range is in between 500 to 2500.
# * Most of the cluster 1 customers income range is in between 0 to 55000 and spending range is in between 0 to 550.
# * Most of the cluster 2 customers income range is in between 30000 to 70000 and spending range is in between 0 to 550.
# * Most of the cluster 3 customers income range is in between 20000 to 80000 and spending range is in between 400 to 1800.

# %%
print(f"Let's have a look on the characteristics of the clusters on the basis of spending :")

_, axes = plt.subplots(figsize=(30,10))
sns.boxenplot(x=data["Clusters"], y=data["Spent"], palette=["#B9C0C9","#682F2F", "#9F8A78","#F3AB60"])
# sns.swarmplot(x=data["Clusters"],y=data["Spent"],color="#B9C0C9",marker="o",size=10,alpha=0.6,linewidth=0,edgecolor="white")

axes.set_title("\nSpending Based Clustering Profile\n",fontsize=25)
axes.set_ylabel("Spending",fontsize=20)
axes.set_xlabel("\nCluster",fontsize=20)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the characteristics of the clusters on the basis of spending :

# %% [markdown]
# **Insights:**
#
# * Most of the cluster 0 customers spending range is in between 500 to 2250.
# * Most of the cluster 1 customers spending range is in between 0 to 500.
# * Most of the cluster 2 customers spending range is in between 0 to 500.
# * Most of the cluster 3 customers spending range is in between 450 to 1900.

# %%
print(f"Let's have a look on the characteristics of the clusters on the basis of accepting promotions :")

plt.subplots(figsize=(20, 8))
p = sns.countplot(x=data["Total Promo"],hue=data["Clusters"],palette=["#B9C0C9","#682F2F", "#9F8A78","#F3AB60"], saturation=1,edgecolor = "#1c1c1c", linewidth = 2)
p.axes.set_yscale("linear")
p.axes.set_title("\nPromotions Acceptance Based Clustering Profile\n",fontsize=25)
p.axes.set_ylabel("Count",fontsize=20)
p.axes.set_xlabel("\nAccepted Promotions",fontsize=20)
p.axes.set_xticklabels(p.get_xticklabels(),rotation = 0)
for container in p.containers:
    p.bar_label(container,label_type="center",padding=6,size=10,color="black",rotation=0,
    bbox={"boxstyle": "round", "pad": 0.4, "facecolor": "orange", "edgecolor": "white", "linewidth" : 2, "alpha": 1})


sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the characteristics of the clusters on the basis of accepting promotions :

# %% [markdown]
# **Insights:**
#
# * 281 customers of cluster 0, 546 customers of cluster 1, 526 customers of cluster 2 and 401 customers of cluster 3 have not accepted any promotions yet.
# * 123 customers of cluster 0, 52 customers of cluster 1, 47 customers of cluster 2 and 100 customers of cluster 3 have accepted only one promotion.
# * 55 customers of cluster 0, 1 customer of cluster 1, 4 customers of cluster 2 and 21 customers of cluster 3 have accepted two promotions.
# * 37 customers of cluster 0 and 7 customers of cluster 3 have accepted three promotions, while no customers from clusters 1 and 2 have accepted three promotions.
# * 9 customers of cluster 0 and 2 customers of cluster 2 have accepted four promotions, while no customers from clusters 1 and 3 have accepted four promotions.
# * Cluster 0 appears to be the most responsive to promotional campaigns, whereas clusters 1 and 2 show the lowest engagement with promotions.

# %%
print(f"Let's have a look on the characteristics of the clusters on the basis of discount purchases :")

_, axes = plt.subplots(figsize=(30,10))
sns.boxenplot(x=data["Clusters"], y=data["Discount Purchases"], palette=["#B9C0C9","#682F2F", "#9F8A78","#F3AB60"])

axes.set_title("\nDiscount Purchase Based Clustering Profile\n",fontsize=25)
axes.set_ylabel("Discount Purchase",fontsize=20)
axes.set_xlabel("\nCluster",fontsize=20)

sns.despine(left=True, bottom=True)
plt.show()
# Out:
# Let's have a look on the characteristics of the clusters on the basis of discount purchases :

# %% [markdown]
# **Insights:**
#
# * Most of the customers of cluster 0 have completed purchases using discount either 1/2 times.
# * Most of the customers of cluster 1 have completed purchases using discount only one times.
# * Most of the customers of cluster 2 have completed purchases using discount 2 to 5 times.
# * Most of the customers of cluster 3 have completed purchases using discount 1 to 4 times.

# %%
def cluster(feature):
    
    _, axes = plt.subplots(figsize=(20,8))
    sns.kdeplot(x=data[feature], y=data["Spent"], hue =data["Clusters"], kind="kde",height=10, palette=["#B9C0C9","#682F2F", "#9F8A78","#F3AB60"])
    axes.set_title(f"\nClustering Profile On {feature}\n",fontsize=25)
    axes.set_ylabel("Spending",fontsize=20)
    axes.set_xlabel(f"\n{feature}",fontsize=20)
    
    sns.despine(left=True, bottom=True)
    plt.show()

# %%
print(f"Characteristics of clusters based on spending and having childern :")
cluster("Children")
# Out:
# Characteristics of clusters based on spending and having childern :

# %% [markdown]
# **Insights:**
#
# * Customers of cluster 0 mostly have no children, while a smaller proportion have one child. They exhibit the highest spending levels among all clusters, with spending ranging approximately from 900 to 2600.
# * Customers of cluster 1 predominantly have no children or one child. Their spending is generally low, with most customers spending between 0 and 500.
# * Customers of cluster 2 mainly have two children, with some customers having one or three children. Their spending is relatively low and concentrated between 0 and 500.
# * Customers of cluster 3 mostly have one child, while a smaller number have two children. Their spending is moderate to high, ranging approximately from 350 to 2000.
# * Clusters 0 and 3 represent the higher-spending customer segments, whereas clusters 1 and 2 consist primarily of lower-spending customers.
# * Customers with no children (cluster 0) tend to spend significantly more than customers with two or more children (cluster 2), suggesting an inverse relationship between the number of children and spending within these customer segments.

# %%
print(f"Characteristics of clusters based on spending and age :")
cluster("Age")
# Out:
# Characteristics of clusters based on spending and age :

# %% [markdown]
# **Insights:**
#
# * Most of the customers of cluster 0 have age range in between 25 to 50. Their spending range is in between 0 to 500.
# * Most of the customers of cluster 1 have age range in between 30 to 60. Their spending range is in between 550 to 2000.
# * Most of the customers of cluster 2 have age range in between 35 to 60. Their spending range is in between 250 to 1800.
# * Most of the customers of cluster 3 have age range in between 40 to 65. Their spending range is in between 0 to 500.

# %%
print(f"Characteristics of clusters based on spending and education level :")
cluster("Education")
# Out:
# Characteristics of clusters based on spending and education level :

# %% [markdown]
# **Insights:**
#
# * The customers of cluster 0 are graduate or in postgraduate level or in undergraduate level. Their spending range is in between 0 to 500.
# * Most of the customers of cluster 1 are graduate or in postgraduate level. Their spending range is in between 550 to 2000.
# * Most of the customers of cluster 2 are graduate and very few in postgraduate level. Their spending range is in between 250 to 1800.
# * All the customers of cluster 3 are graduate or in postgraduate level and some are in undergraduate level. Their spending range is in between 0 to 500.

# %%
print(f"Characteristics of clusters based on spending and marital status :")
cluster("Marital Status")
# Out:
# Characteristics of clusters based on spending and marital status :

# %% [markdown]
# **Insights:**
#
# * Most of the customers of cluster 0 are married and very few are unmarried. Their spending range is in between 0 to 500.
# * Most of the customers of cluster 1 are married. Their spending range is in between 550 to 2000.
# * Most of the customers of cluster 2 are married. Their spending range is in between 250 to 1800.
# * Some customers of cluster 3 are married and some are unmarried. Their spending range is in between 0 to 500.

# %%
print(f"Characteristics of clusters based on spending and parental status :")
cluster("Parental Status")
# Out:
# Characteristics of clusters based on spending and parental status :

# %% [markdown]
# **Insights:**
#
# * Most of the customers of cluster 0 are parents and very few are not parents. Their spending range is in between 0 to 500.
# * All the customers of cluster 1 are not parents. Their spending range is in between 550 to 2000.
# * All the customers of cluster 2 are parents. Their spending range is in between 250 to 1800.
# * All the customers of cluster 3 are parents. Their spending range is in between 0 to 500.

# %%
print(f"Characteristics of clusters based on spending and customer loyalty :")
cluster("Customer Loyalty")
# Out:
# Characteristics of clusters based on spending and customer loyalty :

# %% [markdown]
# **Insights:**
#
# * Most of the customers of cluster 0 are customer for 300 to 900 days. Their spending range is in between 0 to 500.
# * Most of the customers of cluster 1 are customer for 250 to 750 days. Their spending range is in between 550 to 2000.
# * Most of the customers of cluster 2 are customer for 400 to 800 days. Their spending range is in between 250 to 1800.
# * Most of the customers of cluster 3 are customer for 150 to 650 days. Their spending range is in between 0 to 500.

# %% [markdown]
# # Customer's Cluster Profiling

# %% [markdown]
# <p>
# <h3><font color="#682F2F">📌Cluster 0</font></h3>
# 👉 Income range is in between 5000 to 40000 and spending range is in between 0 to 500<br>
# 👉 Age range in between 25 to 50<br>
# 👉 From any educational level<br>
# 👉 Can be married and unmarried as well<br>
# 👉 Most of them are parents<br>
# 👉 Some have one child<br>
# 👉 Customer for at least 300 days<br>
# 👉 Promotion acceptance is rare<br>
# 👉 Very few complete purchases using discounts<br>
#
# <h3><font color="#682F2F">📌Cluster 1</font></h3>
# 👉 Income range is in between 65000 to 85000 and spending range is in between 550 to 2000<br>
# 👉 Age range in between 30 to 60<br>
# 👉 Almost all have completed graduation<br>
# 👉 Most of them are married<br>
# 👉 They are not parents<br>
# 👉 Have no child<br>
# 👉 Customer for at least 250 days<br>
# 👉 Promotion acceptance ratio is 0.5<br>
# 👉 Completing purchases using discounts are rare<br>
#
# <h3><font color="#682F2F">📌Cluster 2</font></h3>
# 👉 Income range is in between 50000 to 80000 and spending range is in between 250 to 1800<br>
# 👉 Age range in between 35 to 60<br>
# 👉 Almost all have completed graduation<br>
# 👉 Most of them are married<br>
# 👉 They are parents<br>
# 👉 All have children, most have one child<br>
# 👉 Customer for at least 400 days<br>
# 👉 Promotion acceptance ratio is poor<br>
# 👉 Highly interested in completing purchases using discounts<br>
#
# <h3><font color="#682F2F">📌Cluster 3</font></h3>
# 👉 Income range is in between 40000 to 60000 and spending range is in between 0 to 500<br>
# 👉 Age range in between 40 to 65<br>
# 👉 Almost all have completed graduation<br>
# 👉 Can be married and unmarried as well<br>
# 👉 They are parents<br>
# 👉 All have children, most have two children<br>
# 👉 Customer for at least 150 days<br>
# 👉 Promotion acceptance is rare<br>
# 👉 Highly interested in completing purchases using discounts<br>
#
# </p>
